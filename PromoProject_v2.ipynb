# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import seaborn as sns
from matplotlib import style

# %%
sales_data = pd.read_parquet("sale_data.parquet")
promo_data = pd.read_excel("promo_data.xlsx")

df_sales = pd.DataFrame(sales_data)
df_promo = pd.DataFrame(promo_data)

df_sales['Date'] = pd.to_datetime(df_sales['Date']).dt.date

# %%
df_sales
# Out:
#                 Date  LocationId  MainDistributorId  DistributorId  PackageId  \
# 0         2023-01-02     2873114            2879223        2878715        615
# 1         2023-01-16     2872993            2879223        2878715        615
# 2         2023-01-18     2918671            2879223        2878715        615
# 3         2023-01-19     2919833            2879223        2878715        615
# 4         2023-01-02     2873114            2879223        2878715        616
# ...              ...         ...                ...            ...        ...
# 11422788  2022-12-22     2928593            2927450        2927451       1052
# 11422789  2022-12-12     2928640            2927450        2927451        505
# 11422790  2022-12-27     2928662            2927450        2927451       1052
# 11422791  2022-12-22     2928741            2927450        2927451       1038
# 11422792  2022-12-22     2928741            2927450        2927451       1052
#
#           ProductId       City  District  BrickId  PaidQty  FreeQty
# 0                38    Kütahya    MERKEZ   430002       24       12
# 1                38    Kütahya  ALTINTAŞ   430101        7        3
# 2                38      Afyon    MERKEZ    30002        7        3
# 3                38       Uşak    MERKEZ   640001        7        3
# 4                38    Kütahya    MERKEZ   430002       24       12
# ...             ...        ...       ...      ...      ...      ...
# 11422788         72  Şanlıurfa   SİVEREK   630701        3        0
# 11422789         45  Şanlıurfa   SİVEREK  1000000        5        0
# 11422790         72  Şanlıurfa  AKÇAKALE   630101        5        0
# 11422791         64  Şanlıurfa   SİVEREK  1000000        2        0
# 11422792         72  Şanlıurfa   SİVEREK  1000000       10        0
#
# [9009211 rows x 11 columns]

# %%
df_sales.describe()
# Out:
#          LocationId  MainDistributorId  DistributorId     PackageId  \
# count  9.009211e+06       9.009211e+06   9.009211e+06  9.009211e+06
# mean   2.881123e+06       2.880518e+06   2.881863e+06  3.049116e+03
# std    2.276591e+04       6.658115e+03   1.049600e+04  1.060543e+04
# min    2.853627e+06       2.879223e+06   2.878715e+06  3.170000e+02
# 25%    2.863949e+06       2.879249e+06   2.878789e+06  5.020000e+02
# 50%    2.873490e+06       2.879260e+06   2.878817e+06  5.410000e+02
# 75%    2.888142e+06       2.879266e+06   2.878857e+06  1.038000e+03
# max    2.931082e+06       2.929489e+06   2.930513e+06  6.960800e+04
#
#           ProductId       BrickId       PaidQty       FreeQty
# count  9.009211e+06  9.009211e+06  9.009211e+06  9.009211e+06
# mean   4.416584e+01  3.315863e+05  6.044765e+00  5.334650e-01
# std    3.279235e+01  1.978870e+05  1.195648e+01  4.134231e+00
# min    1.400000e+01  1.010100e+04  0.000000e+00  0.000000e+00
# 25%    2.000000e+01  1.700020e+05  2.000000e+00  0.000000e+00
# 50%    3.800000e+01  3.416090e+05  4.000000e+00  0.000000e+00
# 75%    6.400000e+01  4.300010e+05  6.000000e+00  0.000000e+00
# max    1.630000e+02  1.000000e+06  3.906000e+03  1.650000e+03

# %%
df_sales[["MainDistributorId", "DistributorId"]].drop_duplicates().groupby(["DistributorId"]).size().reset_index(name='counts')["counts"].unique()
# Out:
# array([1])

# %%
df_sales[["MainDistributorId", "DistributorId"]].drop_duplicates().groupby(["MainDistributorId"]).size().reset_index(name='counts')
# Out:
#     MainDistributorId  counts
# 0             2879223       1
# 1             2879224       1
# 2             2879231       1
# 3             2879236       1
# 4             2879238       1
# 5             2879239       1
# 6             2879244       1
# 7             2879249      20
# 8             2879254       1
# 9             2879257       1
# 10            2879258       1
# 11            2879260       6
# 12            2879266      26
# 13            2879267       1
# 14            2879270       1
# 15            2879276       1
# 16            2886479       1
# 17            2887564       1
# 18            2888200       1
# 19            2909124       1
# 20            2915715       4
# 21            2918750       1
# 22            2922692       1
# 23            2923480       1
# 24            2927151       1
# 25            2927450       1
# 26            2929489       1

# %%
df_sales["ProductId"].unique() # 20
# Out:
# array([ 38,  49,  20,  21,  14,  39,  32,  41,  16,  30, 148,  45, 138,
#         64,  72,  29,  76,  15,  25, 163])

# %%
len(df_sales["BrickId"].unique()) # Brick
# Out:
# 1002

# %%
len(df_sales["PackageId"].unique()) # Nedir bu package id?
# Out:
# 84

# %%
df_sales['TotalQty'] = df_sales['PaidQty'] + df_sales['FreeQty']
df_sales["PromoRatio"] = df_sales.FreeQty/(df_sales.PaidQty+df_sales.FreeQty)
df_sales["IsPromoted"] = df_sales["FreeQty"]!=0

# %%
df_sales
# Out:
#                 Date  LocationId  MainDistributorId  DistributorId  PackageId  \
# 0         2023-01-02     2873114            2879223        2878715        615
# 1         2023-01-16     2872993            2879223        2878715        615
# 2         2023-01-18     2918671            2879223        2878715        615
# 3         2023-01-19     2919833            2879223        2878715        615
# 4         2023-01-02     2873114            2879223        2878715        616
# ...              ...         ...                ...            ...        ...
# 11422788  2022-12-22     2928593            2927450        2927451       1052
# 11422789  2022-12-12     2928640            2927450        2927451        505
# 11422790  2022-12-27     2928662            2927450        2927451       1052
# 11422791  2022-12-22     2928741            2927450        2927451       1038
# 11422792  2022-12-22     2928741            2927450        2927451       1052
#
#           ProductId       City  District  BrickId  PaidQty  FreeQty  TotalQty  \
# 0                38    Kütahya    MERKEZ   430002       24       12        36
# 1                38    Kütahya  ALTINTAŞ   430101        7        3        10
# 2                38      Afyon    MERKEZ    30002        7        3        10
# 3                38       Uşak    MERKEZ   640001        7        3        10
# 4                38    Kütahya    MERKEZ   430002       24       12        36
# ...             ...        ...       ...      ...      ...      ...       ...
# 11422788         72  Şanlıurfa   SİVEREK   630701        3        0         3
# 11422789         45  Şanlıurfa   SİVEREK  1000000        5        0         5
# 11422790         72  Şanlıurfa  AKÇAKALE   630101        5        0         5
# 11422791         64  Şanlıurfa   SİVEREK  1000000        2        0         2
# 11422792         72  Şanlıurfa   SİVEREK  1000000       10        0        10
#
#           PromoRatio  IsPromoted
# 0           0.333333        True
# 1           0.300000        True
# 2           0.300000        True
# 3           0.300000        True
# 4           0.333333        True
# ...              ...         ...
# 11422788    0.000000       False
# 11422789    0.000000       False
# 11422790    0.000000       False
# 11422791    0.000000       False
# 11422792    0.000000       False
#
# [9009211 rows x 14 columns]

# %%
corr_matrix_a = df_sales[["PaidQty", "FreeQty", "IsPromoted", "PromoRatio"]].corr()
sns.heatmap(corr_matrix_a, annot=True)
plt.show()

# %%
df_promo["PromoRatio"] = df_promo.FreeQty/(df_promo.PaidQty+df_promo.FreeQty)
df_promo["PromoPeriod"] = df_promo.EndDate - df_promo.BeginDate
df_promo.rename(columns={"MProductId":"ProductId"}, inplace=True)

df_promo
# Out:
#       ProductId  BeginDate             EndDate  PaidQty  FreeQty  PromoRatio  \
# 0            14 2022-01-01 2022-01-31 23:30:00        6        2    0.250000
# 1            14 2022-01-01 2022-01-31 23:30:00       12        5    0.294118
# 2            14 2022-01-01 2022-01-31 23:30:00       24       12    0.333333
# 3            14 2022-02-01 2022-02-28 23:30:00        6        2    0.250000
# 4            14 2022-02-01 2022-02-28 23:30:00       12        5    0.294118
# ...         ...        ...                 ...      ...      ...         ...
# 1401        148 2023-10-10 2023-10-12 23:30:00       10        1    0.090909
# 1402        148 2023-10-10 2023-10-12 23:30:00       10        4    0.285714
# 1403        148 2023-10-10 2023-10-12 23:30:00       25        3    0.107143
# 1404        148 2023-10-10 2023-10-12 23:30:00       50       10    0.166667
# 1405        148 2023-10-10 2023-10-12 23:30:00      100       25    0.200000
#
#           PromoPeriod
# 0    30 days 23:30:00
# 1    30 days 23:30:00
# 2    30 days 23:30:00
# 3    27 days 23:30:00
# 4    27 days 23:30:00
# ...               ...
# 1401  2 days 23:30:00
# 1402  2 days 23:30:00
# 1403  2 days 23:30:00
# 1404  2 days 23:30:00
# 1405  2 days 23:30:00
#
# [1406 rows x 7 columns]

# %%
# Normalde olması gerekenden fazla row var

merged_data = pd.merge(df_promo, df_sales, on=["ProductId","PaidQty","FreeQty","PromoRatio"])
merged_data
# Out:
#           ProductId  BeginDate             EndDate  PaidQty  FreeQty  \
# 0                14 2022-01-01 2022-01-31 23:30:00        6        2
# 1                14 2022-01-01 2022-01-31 23:30:00        6        2
# 2                14 2022-01-01 2022-01-31 23:30:00        6        2
# 3                14 2022-01-01 2022-01-31 23:30:00        6        2
# 4                14 2022-01-01 2022-01-31 23:30:00        6        2
# ...             ...        ...                 ...      ...      ...
# 38387081        148 2023-10-10 2023-10-12 23:30:00      100       25
# 38387082        148 2023-10-10 2023-10-12 23:30:00      100       25
# 38387083        148 2023-10-10 2023-10-12 23:30:00      100       25
# 38387084        148 2023-10-10 2023-10-12 23:30:00      100       25
# 38387085        148 2023-10-10 2023-10-12 23:30:00      100       25
#
#           PromoRatio      PromoPeriod        Date  LocationId  \
# 0               0.25 30 days 23:30:00  2023-01-12     2924460
# 1               0.25 30 days 23:30:00  2023-08-16     2853652
# 2               0.25 30 days 23:30:00  2023-08-16     2853652
# 3               0.25 30 days 23:30:00  2022-02-14     2873114
# 4               0.25 30 days 23:30:00  2022-02-19     2872993
# ...              ...              ...         ...         ...
# 38387081        0.20  2 days 23:30:00  2023-09-18     2914891
# 38387082        0.20  2 days 23:30:00  2023-09-18     2887274
# 38387083        0.20  2 days 23:30:00  2023-09-19     2860812
# 38387084        0.20  2 days 23:30:00  2023-09-18     2861710
# 38387085        0.20  2 days 23:30:00  2023-09-18     2909787
#
#           MainDistributorId  DistributorId  PackageId      City   District  \
# 0                   2879266        2878857        653  İstanbul     PENDİK
# 1                   2879249        2878789        652     Adana    YÜREĞİR
# 2                   2879249        2878789        653     Adana    YÜREĞİR
# 3                   2879223        2878715        653   Kütahya     MERKEZ
# 4                   2879223        2878715        653   Kütahya   ALTINTAŞ
# ...                     ...            ...        ...       ...        ...
# 38387081            2879266        2886435      47280   Kayseri  KOCASİNAN
# 38387082            2879266        2886435      47280   Kayseri  MELİKGAZİ
# 38387083            2886479        2886480      47280  İstanbul      FATİH
# 38387084            2915715        2919960      47280  İstanbul  KAĞITHANE
# 38387085            2915715        2925802      47280    Ankara     SİNCAN
#
#           BrickId  TotalQty  IsPromoted
# 0          342103         8        True
# 1           10201         8        True
# 2           10201         8        True
# 3          430001         8        True
# 4          430101         8        True
# ...           ...       ...         ...
# 38387081   380103       125        True
# 38387082   380203       125        True
# 38387083   341302       125        True
# 38387084   341706       125        True
# 38387085    60703       125        True
#
# [38387086 rows x 17 columns]

# %%
# Frequency = Barem bazında promosyon kaç defa uygulandı (Promosyon dönemlerine göre group by yapamadım)
promo_sensitivity = merged_data.groupby(["ProductId","PaidQty","FreeQty","PromoRatio"]).size().reset_index(name='Frequency')

promo_sensitivity["TotalPaidQty"] = promo_sensitivity["PaidQty"]*promo_sensitivity["Frequency"]
promo_sensitivity["TotalFreeQty"] = promo_sensitivity["FreeQty"]*promo_sensitivity["Frequency"]
promo_sensitivity["TotalQty"] = promo_sensitivity["TotalPaidQty"]+promo_sensitivity["TotalFreeQty"]


# Promosyon uygulanmayan satışlardaki durum
no_promo_sensitivity = df_sales[(df_sales["IsPromoted"] == False)].groupby(["ProductId","PaidQty","FreeQty","PromoRatio"]).size().reset_index(name='Frequency')

no_promo_sensitivity["TotalPaidQty"] = no_promo_sensitivity["PaidQty"]*no_promo_sensitivity["Frequency"]
no_promo_sensitivity["TotalFreeQty"] = no_promo_sensitivity["FreeQty"]*no_promo_sensitivity["Frequency"]
no_promo_sensitivity["TotalQty"] = no_promo_sensitivity["TotalPaidQty"]+no_promo_sensitivity["TotalFreeQty"]

# %%
promo_sensitivity[promo_sensitivity["ProductId"] == 14]
# Out:
#    ProductId  PaidQty  FreeQty  PromoRatio  Frequency  TotalPaidQty  \
# 0         14        5        1    0.166667    2012985      10064925
# 1         14        6        2    0.250000      18198        109188
# 2         14       10        4    0.285714      23085        230850
# 3         14       12        5    0.294118      70488        845856
# 4         14       15        5    0.250000      30368        455520
# 5         14       20       10    0.333333       3573         71460
# 6         14       24       12    0.333333      33100        794400
# 7         14       25       15    0.375000       2430         60750
#
#    TotalFreeQty  TotalQty
# 0       2012985  12077910
# 1         36396    145584
# 2         92340    323190
# 3        352440   1198296
# 4        151840    607360
# 5         35730    107190
# 6        397200   1191600
# 7         36450     97200

# %%
no_promo_sensitivity[no_promo_sensitivity["ProductId"] == 14]
# Out:
#     ProductId  PaidQty  FreeQty  PromoRatio  Frequency  TotalPaidQty  \
# 0          14        1        0         0.0      25717         25717
# 1          14        2        0         0.0      16330         32660
# 2          14        3        0         0.0       7570         22710
# 3          14        4        0         0.0       5083         20332
# 4          14        5        0         0.0        419          2095
# 5          14        6        0         0.0         51           306
# 6          14        7        0         0.0         23           161
# 7          14        8        0         0.0         13           104
# 8          14        9        0         0.0          1             9
# 9          14       10        0         0.0         23           230
# 10         14       12        0         0.0          3            36
# 11         14       14        0         0.0          1            14
# 12         14       15        0         0.0          4            60
# 13         14       25        0         0.0          2            50
#
#     TotalFreeQty  TotalQty
# 0              0     25717
# 1              0     32660
# 2              0     22710
# 3              0     20332
# 4              0      2095
# 5              0       306
# 6              0       161
# 7              0       104
# 8              0         9
# 9              0       230
# 10             0        36
# 11             0        14
# 12             0        60
# 13             0        50

# %%
promotion_count = len(df_sales[df_sales["IsPromoted"]==True])
promotion_count
# Out:
# 1467515

# %%
no_promotion_count = len(df_sales[df_sales["IsPromoted"]==False])
no_promotion_count
# Out:
# 7541696

# %%
promotion_count/(no_promotion_count+promotion_count)
# Out:
# 0.1628905128318118

# %%
sum(promo_sensitivity.Frequency)
# Out:
# 38387086

# %%
sum(no_promo_sensitivity.Frequency)
# Out:
# 7541696

# %%
df_promo["ProductId"].unique() # 13
# Out:
# array([ 14,  16,  20,  21,  29,  30,  32,  38,  39,  41,  49, 138, 148])

# %%
# Promo datasında olmayan ürünler
no_promotion_products = set(df_sales["ProductId"].unique()).difference(df_promo["ProductId"].unique())
no_promotion_products
# Out:
# {15, 25, 45, 64, 72, 76, 163}

# %%
# En az promolu ürün 163
sum(df_sales[df_sales["ProductId"]==163]["FreeQty"])
# Out:
# 10

# %%
mean_sales = (df_sales.PaidQty.mean(), df_sales.FreeQty.mean(), df_sales.PromoRatio.mean())
mean_promo = (df_promo.PaidQty.mean(), df_promo.FreeQty.mean(), df_promo.PromoRatio.mean())
mean_period = df_promo.PromoPeriod.mean()

# %%
print("Sales Data Averages")
print("(Paid Quantity, Free Quantity, Promotion Ratio) = ", mean_sales)
# Out:
# Sales Data Averages
# (Paid Quantity, Free Quantity, Promotion Ratio) =  (6.0447649633247575, 0.5334650281806032, 0.02775465564209698)

# %%
print("Average Promotion Period = ", mean_period)
# Out:
# Average Promotion Period =  19 days 11:33:01.792318634

# %%
df_promo["PromoPeriod"].unique()
# Out:
# <TimedeltaArray>
# ['30 days 23:30:00', '27 days 23:30:00', '29 days 23:30:00',
#   '1 days 23:30:00',  '2 days 23:30:00', '16 days 23:30:00',
#   '4 days 23:30:00',  '3 days 23:30:00',  '5 days 23:30:00',
#  '24 days 23:30:00', '14 days 23:30:00',  '0 days 23:30:00',
#  '26 days 23:30:00', '17 days 23:30:00', '23 days 23:30:00',
#   '6 days 23:30:00', '28 days 23:30:00', '10 days 23:30:00',
#  '21 days 23:30:00',  '2 days 23:00:00', '12 days 23:30:00',
#  '11 days 23:30:00']
# Length: 22, dtype: timedelta64[ns]

# %%
x = df_sales["PromoRatio"]
y = df_sales["PaidQty"]

plt.figure(figsize=(7,7))
plt.style.use('ggplot')
plt.scatter(x, y, c ="tomato", s = 7)
plt.xlabel("Promotion Ratio")
plt.ylabel("Paid Quantity")
                      
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.plot(x, p(x), c="royalblue")
plt.show()

df_sales["PromoRatio"]
# Out:
# 0           0.333333
# 1           0.300000
# 2           0.300000
# 3           0.300000
# 4           0.333333
#               ...
# 11422788    0.000000
# 11422789    0.000000
# 11422790    0.000000
# 11422791    0.000000
# 11422792    0.000000
# Name: PromoRatio, Length: 9009211, dtype: float64

# %%
sales_sensitivity = df_sales.groupby(["ProductId","Date", "IsPromoted"])["TotalQty"].sum().reset_index(name='TotalQty')
promoted_sales = sales_sensitivity[sales_sensitivity["IsPromoted"]==True]
not_promoted_sales = sales_sensitivity[sales_sensitivity["IsPromoted"]==False]

# %%
sales_sensitivity[sales_sensitivity["ProductId"]==14]
# Out:
#       ProductId        Date  IsPromoted  TotalQty
# 0            14  2022-02-01       False       786
# 1            14  2022-02-01        True      4135
# 2            14  2022-02-02       False       506
# 3            14  2022-02-02        True      3882
# 4            14  2022-02-03       False       491
# ...         ...         ...         ...       ...
# 1198         14  2023-09-28        True       656
# 1199         14  2023-09-29       False       131
# 1200         14  2023-09-29        True       638
# 1201         14  2023-09-30       False        51
# 1202         14  2023-09-30        True       160
#
# [1203 rows x 4 columns]

# %%
ts_a = promoted_sales[(promoted_sales["ProductId"] == 14) & (promoted_sales["Date"] < dt.date(2022, 6, 1))]
ts_b = not_promoted_sales[(not_promoted_sales["ProductId"] == 14) & (not_promoted_sales["Date"] < dt.date(2022, 6, 1))]

plt.figure(figsize=(15,10))
plt.style.use('ggplot')

plt.plot(ts_a["Date"], ts_a["TotalQty"], linewidth = 2)
plt.plot(ts_b["Date"], ts_b["TotalQty"], linewidth = 2)

 

plt.title('Time Series Plot')
plt.xlabel('Time')
plt.ylabel('Total Quantity (Paid + Free)')
plt.xticks(rotation=45)
plt.show()
