# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import seaborn as sns
from matplotlib import style
import math
import random

# %%
#LP MAXIMIZATION MODEL

from pulp import *
Promo_Model = LpProblem("Pharma_Promotion_Model", LpMaximize)

# %%
#PARAMETERS

T=12 # end of promotion horizon
PHorizon = list(range(0, T))

I=10 # product count 
Products = list(range(0, I))

#NOT USED RIGHT NOW
Promo_Levels = [0,1,2]

Demand = np.zeros((I, T), dtype = int)

for i in Products:
    for t in PHorizon:
        Demand[i][t] = random.randint(0, 10000)
    
Promo_Sensitivity = np.zeros(I, dtype = float)
for i in Products:
    Promo_Sensitivity[i] = random.uniform(0.75, 1)


Total_PaidQty_Limit = 1000000
Total_FreeQty_Limit = 250000

Promo_Sensitivity
# Out:
# array([0.97671939, 0.76227342, 0.81819194, 0.83515284, 0.8657577 ,
#        0.89283139, 0.95198538, 0.80268148, 0.90668868, 0.87407859])

# %%
#DECISION VARIABLES

#Paid Quantity
PaidQtyLimit = 20000
P = LpVariable.dicts("Paid_Quantity",(Products,PHorizon),lowBound=0, upBound=PaidQtyLimit, cat='Integer')

#Free Quantity
FreeQtyLimit = 5000
F = LpVariable.dicts("Free_Quantity",(Products,PHorizon),lowBound=0, upBound=FreeQtyLimit, cat='Integer')

#Is Product "i" at Time "t" Promoted?
X = LpVariable.dicts("IsPromoted",(Products,PHorizon),cat='Binary')

#Promo Ratio
#R = LpVariable.dicts("Promo_Ratio",(Products,PHorizon),lowBound=0, upBound=1, cat='Continuous')

# %%
#OBJECTIVE FUNCTION

Total_Paid_Quantity = lpSum(lpSum(P[i][t] for i in Products) for t in PHorizon)

Promo_Model += Total_Paid_Quantity

# %%
#DEMAND SATISFACTION
for i in Products:
    for t in PHorizon:
        Promo_Model += P[i][t] + F[i][t] <= Demand[i][t]*(1 + Promo_Sensitivity[i]*F[i][t]*(1/FreeQtyLimit))
    
#NO FREE QTY WITHOUT PROMOTION
M = FreeQtyLimit
for i in Products:
    for t in PHorizon:
        Promo_Model += F[i][t] <= X[i][t]*M
        Promo_Model += F[i][t] >= X[i][t]-0.5

#PROMOTED PRODUCTS AT TIME "t"
Promoted_Products = 7
for t in PHorizon:
    Promo_Model += lpSum(X[i][t] for i in Products) <= Promoted_Products
    
#PROMO PERIOD FOR PRODUCT "i"  
Max_Promo_Duration = 4
Min_Promo_Duration = 1
for i in Products:
    Promo_Model += lpSum(X[i][t] for t in PHorizon) <= Max_Promo_Duration
    Promo_Model += lpSum(X[i][t] for t in PHorizon) >= Min_Promo_Duration
    
#TOTAL PAID QUANTITY CAPACITY
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(P[i][t] for t in PHorizon) <= Total_PaidQty_Limit
    
#TOTAL FREE QUANTITY CAPACITY
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(F[i][t] for t in PHorizon) <= Total_FreeQty_Limit

# %%
solver = GUROBI()
solver.solve(Promo_Model)

# The status of the solution is printed to the screen
print("Status:", LpStatus[Promo_Model.status])
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 632 rows, 360 columns and 3960 nonzeros
# Model fingerprint: 0x375c6803
# Variable types: 0 continuous, 360 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [3e-03, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+04]
#   RHS range        [5e-01, 1e+06]
# Found heuristic solution: objective 639628.00000
# Presolve removed 600 rows and 240 columns
# Presolve time: 0.00s
# Presolved: 32 rows, 120 columns, 360 nonzeros
# Found heuristic solution: objective 724602.00000
# Variable types: 0 continuous, 120 integer (120 binary)
# Found heuristic solution: objective 728719.00000
#
# Root relaxation: cutoff, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      728719.000 728719.000  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 728719 724602 639628
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.287190000000e+05, best bound 7.287190000000e+05, gap 0.0000%
# Gurobi status= 2
# Status: Optimal

# %%
# OUTPUT

# OPTIMIZED OBJECTIVE FUNCTION
print("Optimal Total Paid Quantity = ", pulp.value(Promo_Model.objective),"\n")

# PRINTS VARIABLES AND OPTIMAL VALUES
for v in Promo_Model.variables():
    print(v.name, "=", v.varValue)
# Out:
# Optimal Total Paid Quantity =  728719.0
#
# Free_Quantity_0_0 = 0.0
# Free_Quantity_0_1 = 5000.0
# Free_Quantity_0_10 = 5000.0
# Free_Quantity_0_11 = 0.0
# Free_Quantity_0_2 = 5000.0
# Free_Quantity_0_3 = 5000.0
# Free_Quantity_0_4 = 0.0
# Free_Quantity_0_5 = 0.0
# Free_Quantity_0_6 = 0.0
# Free_Quantity_0_7 = 0.0
# Free_Quantity_0_8 = 0.0
# Free_Quantity_0_9 = 0.0
# Free_Quantity_1_0 = 0.0
# Free_Quantity_1_1 = 0.0
# Free_Quantity_1_10 = 0.0
# Free_Quantity_1_11 = 0.0
# Free_Quantity_1_2 = 5000.0
# Free_Quantity_1_3 = 5000.0
# Free_Quantity_1_4 = 0.0
# Free_Quantity_1_5 = 0.0
# Free_Quantity_1_6 = 5000.0
# Free_Quantity_1_7 = 0.0
# Free_Quantity_1_8 = 5000.0
# Free_Quantity_1_9 = 0.0
# Free_Quantity_2_0 = 5000.0
# Free_Quantity_2_1 = 0.0
# Free_Quantity_2_10 = 0.0
# Free_Quantity_2_11 = 0.0
# Free_Quantity_2_2 = 5000.0
# Free_Quantity_2_3 = 0.0
# Free_Quantity_2_4 = 0.0
# Free_Quantity_2_5 = 5000.0
# Free_Quantity_2_6 = 0.0
# Free_Quantity_2_7 = 5000.0
# Free_Quantity_2_8 = 0.0
# Free_Quantity_2_9 = 0.0
# Free_Quantity_3_0 = 0.0
# Free_Quantity_3_1 = 0.0
# Free_Quantity_3_10 = 0.0
# Free_Quantity_3_11 = 5000.0
# Free_Quantity_3_2 = 0.0
# Free_Quantity_3_3 = 0.0
# Free_Quantity_3_4 = 5000.0
# Free_Quantity_3_5 = 0.0
# Free_Quantity_3_6 = 5000.0
# Free_Quantity_3_7 = 0.0
# Free_Quantity_3_8 = 0.0
# Free_Quantity_3_9 = 0.0
# Free_Quantity_4_0 = 0.0
# Free_Quantity_4_1 = 0.0
# Free_Quantity_4_10 = 5000.0
# Free_Quantity_4_11 = 0.0
# Free_Quantity_4_2 = 0.0
# Free_Quantity_4_3 = 0.0
# Free_Quantity_4_4 = 0.0
# Free_Quantity_4_5 = 0.0
# Free_Quantity_4_6 = 5000.0
# Free_Quantity_4_7 = 5000.0
# Free_Quantity_4_8 = 0.0
# Free_Quantity_4_9 = 5000.0
# Free_Quantity_5_0 = 5000.0
# Free_Quantity_5_1 = 5000.0
# Free_Quantity_5_10 = 0.0
# Free_Quantity_5_11 = 0.0
# Free_Quantity_5_2 = 0.0
# Free_Quantity_5_3 = 0.0
# Free_Quantity_5_4 = 0.0
# Free_Quantity_5_5 = 0.0
# Free_Quantity_5_6 = 0.0
# Free_Quantity_5_7 = 5000.0
# Free_Quantity_5_8 = 5000.0
# Free_Quantity_5_9 = 0.0
# Free_Quantity_6_0 = 0.0
# Free_Quantity_6_1 = 0.0
# Free_Quantity_6_10 = 5000.0
# Free_Quantity_6_11 = 0.0
# Free_Quantity_6_2 = 5000.0
# Free_Quantity_6_3 = 0.0
# Free_Quantity_6_4 = 5000.0
# Free_Quantity_6_5 = 0.0
# Free_Quantity_6_6 = 0.0
# Free_Quantity_6_7 = 0.0
# Free_Quantity_6_8 = 5000.0
# Free_Quantity_6_9 = 0.0
# Free_Quantity_7_0 = 0.0
# Free_Quantity_7_1 = 0.0
# Free_Quantity_7_10 = 0.0
# Free_Quantity_7_11 = 5000.0
# Free_Quantity_7_2 = 5000.0
# Free_Quantity_7_3 = 0.0
# Free_Quantity_7_4 = 0.0
# Free_Quantity_7_5 = 0.0
# Free_Quantity_7_6 = 5000.0
# Free_Quantity_7_7 = 0.0
# Free_Quantity_7_8 = 5000.0
# Free_Quantity_7_9 = 0.0
# Free_Quantity_8_0 = 5000.0
# Free_Quantity_8_1 = 0.0
# Free_Quantity_8_10 = 0.0
# Free_Quantity_8_11 = 0.0
# Free_Quantity_8_2 = 0.0
# Free_Quantity_8_3 = 0.0
# Free_Quantity_8_4 = 5000.0
# Free_Quantity_8_5 = 0.0
# Free_Quantity_8_6 = 5000.0
# Free_Quantity_8_7 = 0.0
# Free_Quantity_8_8 = 5000.0
# Free_Quantity_8_9 = 0.0
# Free_Quantity_9_0 = 0.0
# Free_Quantity_9_1 = 5000.0
# Free_Quantity_9_10 = 0.0
# Free_Quantity_9_11 = 0.0
# Free_Quantity_9_2 = 5000.0
# Free_Quantity_9_3 = 0.0
# Free_Quantity_9_4 = 0.0
# Free_Quantity_9_5 = 0.0
# Free_Quantity_9_6 = 5000.0
# Free_Quantity_9_7 = 0.0
# Free_Quantity_9_8 = 5000.0
# Free_Quantity_9_9 = 0.0
# IsPromoted_0_0 = 0.0
# IsPromoted_0_1 = 1.0
# IsPromoted_0_10 = 1.0
# IsPromoted_0_11 = 0.0
# IsPromoted_0_2 = 1.0
# IsPromoted_0_3 = 1.0
# IsPromoted_0_4 = 0.0
# IsPromoted_0_5 = 0.0
# IsPromoted_0_6 = 0.0
# IsPromoted_0_7 = 0.0
# IsPromoted_0_8 = 0.0
# IsPromoted_0_9 = 0.0
# IsPromoted_1_0 = 0.0
# IsPromoted_1_1 = 0.0
# IsPromoted_1_10 = 0.0
# IsPromoted_1_11 = 0.0
# IsPromoted_1_2 = 1.0
# IsPromoted_1_3 = 1.0
# IsPromoted_1_4 = 0.0
# IsPromoted_1_5 = 0.0
# IsPromoted_1_6 = 1.0
# IsPromoted_1_7 = 0.0
# IsPromoted_1_8 = 1.0
# IsPromoted_1_9 = 0.0
# IsPromoted_2_0 = 1.0
# IsPromoted_2_1 = 0.0
# IsPromoted_2_10 = 0.0
# IsPromoted_2_11 = 0.0
# IsPromoted_2_2 = 1.0
# IsPromoted_2_3 = 0.0
# IsPromoted_2_4 = 0.0
# IsPromoted_2_5 = 1.0
# IsPromoted_2_6 = 0.0
# IsPromoted_2_7 = 1.0
# IsPromoted_2_8 = 0.0
# IsPromoted_2_9 = 0.0
# IsPromoted_3_0 = 0.0
# IsPromoted_3_1 = 0.0
# IsPromoted_3_10 = 0.0
# IsPromoted_3_11 = 1.0
# IsPromoted_3_2 = 0.0
# IsPromoted_3_3 = 0.0
# IsPromoted_3_4 = 1.0
# IsPromoted_3_5 = 0.0
# IsPromoted_3_6 = 1.0
# IsPromoted_3_7 = 0.0
# IsPromoted_3_8 = 0.0
# IsPromoted_3_9 = 0.0
# IsPromoted_4_0 = 0.0
# IsPromoted_4_1 = 0.0
# IsPromoted_4_10 = 1.0
# IsPromoted_4_11 = 0.0
# IsPromoted_4_2 = 0.0
# IsPromoted_4_3 = 0.0
# IsPromoted_4_4 = 0.0
# IsPromoted_4_5 = 0.0
# IsPromoted_4_6 = 1.0
# IsPromoted_4_7 = 1.0
# IsPromoted_4_8 = 0.0
# IsPromoted_4_9 = 1.0
# IsPromoted_5_0 = 1.0
# IsPromoted_5_1 = 1.0
# IsPromoted_5_10 = 0.0
# IsPromoted_5_11 = 0.0
# IsPromoted_5_2 = 0.0
# IsPromoted_5_3 = 0.0
# IsPromoted_5_4 = 0.0
# IsPromoted_5_5 = 0.0
# IsPromoted_5_6 = 0.0
# IsPromoted_5_7 = 1.0
# IsPromoted_5_8 = 1.0
# IsPromoted_5_9 = 0.0
# IsPromoted_6_0 = 0.0
# IsPromoted_6_1 = 0.0
# IsPromoted_6_10 = 1.0
# IsPromoted_6_11 = 0.0
# IsPromoted_6_2 = 1.0
# IsPromoted_6_3 = 0.0
# IsPromoted_6_4 = 1.0
# IsPromoted_6_5 = 0.0
# IsPromoted_6_6 = 0.0
# IsPromoted_6_7 = 0.0
# IsPromoted_6_8 = 1.0
# IsPromoted_6_9 = 0.0
# IsPromoted_7_0 = 0.0
# IsPromoted_7_1 = 0.0
# IsPromoted_7_10 = 0.0
# IsPromoted_7_11 = 1.0
# IsPromoted_7_2 = 1.0
# IsPromoted_7_3 = 0.0
# IsPromoted_7_4 = 0.0
# IsPromoted_7_5 = 0.0
# IsPromoted_7_6 = 1.0
# IsPromoted_7_7 = 0.0
# IsPromoted_7_8 = 1.0
# IsPromoted_7_9 = 0.0
# IsPromoted_8_0 = 1.0
# IsPromoted_8_1 = 0.0
# IsPromoted_8_10 = 0.0
# IsPromoted_8_11 = 0.0
# IsPromoted_8_2 = 0.0
# IsPromoted_8_3 = 0.0
# IsPromoted_8_4 = 1.0
# IsPromoted_8_5 = 0.0
# IsPromoted_8_6 = 1.0
# IsPromoted_8_7 = 0.0
# IsPromoted_8_8 = 1.0
# IsPromoted_8_9 = 0.0
# IsPromoted_9_0 = 0.0
# IsPromoted_9_1 = 1.0
# IsPromoted_9_10 = 0.0
# IsPromoted_9_11 = 0.0
# IsPromoted_9_2 = 1.0
# IsPromoted_9_3 = 0.0
# IsPromoted_9_4 = 0.0
# IsPromoted_9_5 = 0.0
# IsPromoted_9_6 = 1.0
# IsPromoted_9_7 = 0.0
# IsPromoted_9_8 = 1.0
# IsPromoted_9_9 = 0.0
# Paid_Quantity_0_0 = 7655.0
# Paid_Quantity_0_1 = 13662.0
# Paid_Quantity_0_10 = 11041.0
# Paid_Quantity_0_11 = 1349.0
# Paid_Quantity_0_2 = 12078.0
# Paid_Quantity_0_3 = 12254.0
# Paid_Quantity_0_4 = 7714.0
# Paid_Quantity_0_5 = 3561.0
# Paid_Quantity_0_6 = 7014.0
# Paid_Quantity_0_7 = 4733.0
# Paid_Quantity_0_8 = 6884.0
# Paid_Quantity_0_9 = 960.0
# Paid_Quantity_1_0 = 6215.0
# Paid_Quantity_1_1 = 1246.0
# Paid_Quantity_1_10 = 1138.0
# Paid_Quantity_1_11 = 1760.0
# Paid_Quantity_1_2 = 7341.0
# Paid_Quantity_1_3 = 8113.0
# Paid_Quantity_1_4 = 5914.0
# Paid_Quantity_1_5 = 3898.0
# Paid_Quantity_1_6 = 11988.0
# Paid_Quantity_1_7 = 5896.0
# Paid_Quantity_1_8 = 10271.0
# Paid_Quantity_1_9 = 3215.0
# Paid_Quantity_2_0 = 9761.0
# Paid_Quantity_2_1 = 695.0
# Paid_Quantity_2_10 = 3240.0
# Paid_Quantity_2_11 = 403.0
# Paid_Quantity_2_2 = 9903.0
# Paid_Quantity_2_3 = 7167.0
# Paid_Quantity_2_4 = 7339.0
# Paid_Quantity_2_5 = 8525.0
# Paid_Quantity_2_6 = 3399.0
# Paid_Quantity_2_7 = 9916.0
# Paid_Quantity_2_8 = 6240.0
# Paid_Quantity_2_9 = 6070.0
# Paid_Quantity_3_0 = 2652.0
# Paid_Quantity_3_1 = 417.0
# Paid_Quantity_3_10 = 2012.0
# Paid_Quantity_3_11 = 8282.0
# Paid_Quantity_3_2 = 5397.0
# Paid_Quantity_3_3 = 375.0
# Paid_Quantity_3_4 = 9945.0
# Paid_Quantity_3_5 = 3407.0
# Paid_Quantity_3_6 = 6018.0
# Paid_Quantity_3_7 = 5271.0
# Paid_Quantity_3_8 = 274.0
# Paid_Quantity_3_9 = 2752.0
# Paid_Quantity_4_0 = 35.0
# Paid_Quantity_4_1 = 5858.0
# Paid_Quantity_4_10 = 12206.0
# Paid_Quantity_4_11 = 8791.0
# Paid_Quantity_4_2 = 803.0
# Paid_Quantity_4_3 = 4728.0
# Paid_Quantity_4_4 = 7389.0
# Paid_Quantity_4_5 = 752.0
# Paid_Quantity_4_6 = 12267.0
# Paid_Quantity_4_7 = 11642.0
# Paid_Quantity_4_8 = 1431.0
# Paid_Quantity_4_9 = 11870.0
# Paid_Quantity_5_0 = 12118.0
# Paid_Quantity_5_1 = 12786.0
# Paid_Quantity_5_10 = 8555.0
# Paid_Quantity_5_11 = 4203.0
# Paid_Quantity_5_2 = 2324.0
# Paid_Quantity_5_3 = 1074.0
# Paid_Quantity_5_4 = 5660.0
# Paid_Quantity_5_5 = 8485.0
# Paid_Quantity_5_6 = 2921.0
# Paid_Quantity_5_7 = 11753.0
# Paid_Quantity_5_8 = 13192.0
# Paid_Quantity_5_9 = 2237.0
# Paid_Quantity_6_0 = 4993.0
# Paid_Quantity_6_1 = 5893.0
# Paid_Quantity_6_10 = 10325.0
# Paid_Quantity_6_11 = 1227.0
# Paid_Quantity_6_2 = 12766.0
# Paid_Quantity_6_3 = 5930.0
# Paid_Quantity_6_4 = 9577.0
# Paid_Quantity_6_5 = 1406.0
# Paid_Quantity_6_6 = 4460.0
# Paid_Quantity_6_7 = 1808.0
# Paid_Quantity_6_8 = 12374.0
# Paid_Quantity_6_9 = 2311.0
# Paid_Quantity_7_0 = 2215.0
# Paid_Quantity_7_1 = 6633.0
# Paid_Quantity_7_10 = 7637.0
# Paid_Quantity_7_11 = 9300.0
# Paid_Quantity_7_2 = 12217.0
# Paid_Quantity_7_3 = 7626.0
# Paid_Quantity_7_4 = 5171.0
# Paid_Quantity_7_5 = 4959.0
# Paid_Quantity_7_6 = 9078.0
# Paid_Quantity_7_7 = 3500.0
# Paid_Quantity_7_8 = 10625.0
# Paid_Quantity_7_9 = 168.0
# Paid_Quantity_8_0 = 8907.0
# Paid_Quantity_8_1 = 5045.0
# Paid_Quantity_8_10 = 7225.0
# Paid_Quantity_8_11 = 286.0
# Paid_Quantity_8_2 = 5181.0
# Paid_Quantity_8_3 = 2188.0
# Paid_Quantity_8_4 = 12215.0
# Paid_Quantity_8_5 = 3908.0
# Paid_Quantity_8_6 = 10890.0
# Paid_Quantity_8_7 = 7045.0
# Paid_Quantity_8_8 = 9342.0
# Paid_Quantity_8_9 = 3429.0
# Paid_Quantity_9_0 = 3772.0
# Paid_Quantity_9_1 = 9473.0
# Paid_Quantity_9_10 = 191.0
# Paid_Quantity_9_11 = 1557.0
# Paid_Quantity_9_2 = 12093.0
# Paid_Quantity_9_3 = 2865.0
# Paid_Quantity_9_4 = 5533.0
# Paid_Quantity_9_5 = 6626.0
# Paid_Quantity_9_6 = 11602.0
# Paid_Quantity_9_7 = 1033.0
# Paid_Quantity_9_8 = 7648.0
# Paid_Quantity_9_9 = 26.0

# %%
#PROMO RATIO IS CALCULATED BASED ON THE OPTIMUM P[i][t] AND F[i][t] VALUES
Promo_Ratio = np.zeros((I, T), dtype = float)

for i in Products:
    for t in PHorizon:
        Promo_Ratio[i][t] = (F[i][t].varValue)/(P[i][t].varValue + F[i][t].varValue)

df_Promo_Ratio = pd.DataFrame(Promo_Ratio,
                 index=range(1,I+1),
                 columns=range(1,T+1))
df_Promo_Ratio
# Out:
#           1         2         3         4         5         6         7   \
# 1   0.000000  0.267924  0.292774  0.289788  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.405154  0.381301  0.000000  0.000000  0.294325
# 3   0.338730  0.000000  0.335503  0.000000  0.000000  0.369686  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.334560  0.000000  0.453803
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.289570
# 6   0.292090  0.281120  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.281436  0.000000  0.343006  0.000000  0.000000
# 8   0.000000  0.000000  0.290411  0.000000  0.000000  0.000000  0.355164
# 9   0.359531  0.000000  0.000000  0.000000  0.290444  0.000000  0.314663
# 10  0.000000  0.345471  0.292517  0.000000  0.000000  0.000000  0.301169
#
#           8         9         10        11        12
# 1   0.000000  0.000000  0.000000  0.311701  0.000000
# 2   0.000000  0.327418  0.000000  0.000000  0.000000
# 3   0.335211  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.376449
# 5   0.300445  0.000000  0.296384  0.290596  0.000000
# 6   0.298454  0.274846  0.000000  0.000000  0.000000
# 7   0.000000  0.287786  0.000000  0.326264  0.000000
# 8   0.000000  0.320000  0.000000  0.000000  0.349650
# 9   0.000000  0.348626  0.000000  0.000000  0.000000
# 10  0.000000  0.395319  0.000000  0.000000  0.000000

# %%
Promo_Sensitivity
# Out:
# array([0.97671939, 0.76227342, 0.81819194, 0.83515284, 0.8657577 ,
#        0.89283139, 0.95198538, 0.80268148, 0.90668868, 0.87407859])
