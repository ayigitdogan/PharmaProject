# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import seaborn as sns
from matplotlib import style
import math
import random

# %%
#LP MAXIMIZATION MODEL

from pulp import *
Promo_Model = LpProblem("Pharma_Promotion_Model", LpMaximize)

# %%
#PARAMETERS

T=30 # end of promotion horizon
PHorizon = list(range(0, T))

I=10 # product count 
Products = list(range(0, I))

#NOT USED RIGHT NOW
Promo_Levels = [0,1,2]

Base_Demand = np.zeros((I, T), dtype = int)

for i in Products:
    for t in PHorizon:
        Base_Demand[i][t] = random.uniform(4000,6000)
    
Promo_Sensitivity = np.zeros(I, dtype = float)
for i in Products:
    Promo_Sensitivity[i] = random.uniform(6,10)
    
Promo_Sensitivity[0] = 1
Promo_Sensitivity[I-1] = 10


Total_PaidQty_Limit = 1000000
Total_FreeQty_Limit = 250000

Promo_Sensitivity
# Out:
# array([ 1.        ,  7.9533866 ,  6.35054765,  7.24450098,  8.64909589,
#         6.96332305,  7.74080694,  9.7351889 ,  9.00555674, 10.        ])

# %%
#DECISION VARIABLES

#Paid Quantity
PaidQtyLimit = 100000
P = LpVariable.dicts("Paid_Quantity",(Products,PHorizon),lowBound=0, upBound=PaidQtyLimit, cat='Integer')

#Free Quantity
FreeQtyLimit = 5000
F = LpVariable.dicts("Free_Quantity",(Products,PHorizon),lowBound=0, upBound=FreeQtyLimit, cat='Integer')

#Is Product "i" at Time "t" Promoted?
X = LpVariable.dicts("IsPromoted",(Products,PHorizon),cat='Binary')

#Promo Ratio
#R = LpVariable.dicts("Promo_Ratio",(Products,PHorizon),lowBound=0, upBound=1, cat='Continuous')

# %%
#OBJECTIVE FUNCTION

Total_Paid_Quantity = lpSum(lpSum(P[i][t] for i in Products) for t in PHorizon)
Total_Free_Quantity = lpSum(lpSum(F[i][t] for i in Products) for t in PHorizon)

W1 = 100 #average earning from a paid quantity
W2 = 50 #average cost for a given free quantity

Promo_Model += W1*Total_Paid_Quantity - W2*Total_Free_Quantity

# %%
#DEMAND SATISFACTION
for i in Products:
    for t in PHorizon:
        Promo_Model += P[i][t] + F[i][t] <= Base_Demand[i][t] + Promo_Sensitivity[i]*F[i][t]
                                                                                                
#NO FREE QTY WITHOUT PROMOTION
M = FreeQtyLimit
for i in Products:
    for t in PHorizon:
        Promo_Model += F[i][t] <= X[i][t]*M
        Promo_Model += F[i][t] >= X[i][t]-0.5

#PROMOTED PRODUCTS AT TIME "t"
Promoted_Products = 8
for t in PHorizon:
    Promo_Model += lpSum(X[i][t] for i in Products) <= Promoted_Products
    
#PROMO PERIOD FOR PRODUCT "i"  
Max_Promo_Duration = 15
Min_Promo_Duration = 10
for i in Products:
    Promo_Model += lpSum(X[i][t] for t in PHorizon) <= Max_Promo_Duration
    Promo_Model += lpSum(X[i][t] for t in PHorizon) >= Min_Promo_Duration

#TOTAL PAID QUANTITY PER PRODUCT
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(P[i][t] for t in PHorizon) <= Total_PaidQty_Limit
    
#TOTAL FREE QUANTITY PER PRODUCT
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(F[i][t] for t in PHorizon) <= Total_FreeQty_Limit

# %%
solver = GUROBI()
solver.solve(Promo_Model)

# The status of the solution is printed to the screen
print("Status:", LpStatus[Promo_Model.status])
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1550 rows, 900 columns and 20670 nonzeros
# Model fingerprint: 0xa6da0a34
# Variable types: 0 continuous, 900 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [5e+01, 1e+02]
#   Bounds range     [1e+00, 1e+05]
#   RHS range        [5e-01, 1e+06]
# Found heuristic solution: objective 1.494771e+08
# Presolve removed 772 rows and 120 columns
# Presolve time: 0.01s
# Presolved: 778 rows, 780 columns, 2580 nonzeros
# Found heuristic solution: objective 1.858546e+08
# Variable types: 0 continuous, 780 integer (300 binary)
# Found heuristic solution: objective 1.859106e+08
#
# Root relaxation: objective 6.004885e+08, 612 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6.0049e+08    0  216 1.8591e+08 6.0049e+08   223%     -    0s
# H    0     0                    6.004821e+08 6.0049e+08  0.00%     -    0s
#
# Explored 1 nodes (629 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 6.00482e+08 1.85911e+08 1.85855e+08 1.49477e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.004821000000e+08, best bound 6.004885432664e+08, gap 0.0011%
# Gurobi status= 2
# Status: Optimal

# %%
# OUTPUT

# OPTIMIZED OBJECTIVE FUNCTION
print("Optimal Total Paid Quantity = ", pulp.value(Promo_Model.objective),"\n")

# PRINTS VARIABLES AND OPTIMAL VALUES
for v in Promo_Model.variables():
    print(v.name, "=", v.varValue)
# Out:
# Optimal Total Paid Quantity =  600482100.0
#
# Free_Quantity_0_0 = 0.0
# Free_Quantity_0_1 = 0.0
# Free_Quantity_0_10 = 1.0
# Free_Quantity_0_11 = 0.0
# Free_Quantity_0_12 = 1.0
# Free_Quantity_0_13 = 0.0
# Free_Quantity_0_14 = 0.0
# Free_Quantity_0_15 = 0.0
# Free_Quantity_0_16 = 0.0
# Free_Quantity_0_17 = 1.0
# Free_Quantity_0_18 = 1.0
# Free_Quantity_0_19 = 0.0
# Free_Quantity_0_2 = 0.0
# Free_Quantity_0_20 = 1.0
# Free_Quantity_0_21 = 1.0
# Free_Quantity_0_22 = 0.0
# Free_Quantity_0_23 = 0.0
# Free_Quantity_0_24 = 0.0
# Free_Quantity_0_25 = 1.0
# Free_Quantity_0_26 = 0.0
# Free_Quantity_0_27 = 0.0
# Free_Quantity_0_28 = 0.0
# Free_Quantity_0_29 = 0.0
# Free_Quantity_0_3 = 0.0
# Free_Quantity_0_4 = 0.0
# Free_Quantity_0_5 = 1.0
# Free_Quantity_0_6 = 1.0
# Free_Quantity_0_7 = 1.0
# Free_Quantity_0_8 = 0.0
# Free_Quantity_0_9 = 0.0
# Free_Quantity_1_0 = 5000.0
# Free_Quantity_1_1 = 0.0
# Free_Quantity_1_10 = 0.0
# Free_Quantity_1_11 = 0.0
# Free_Quantity_1_12 = 0.0
# Free_Quantity_1_13 = 0.0
# Free_Quantity_1_14 = 0.0
# Free_Quantity_1_15 = 0.0
# Free_Quantity_1_16 = 5000.0
# Free_Quantity_1_17 = 5000.0
# Free_Quantity_1_18 = 5000.0
# Free_Quantity_1_19 = 5000.0
# Free_Quantity_1_2 = 0.0
# Free_Quantity_1_20 = 0.0
# Free_Quantity_1_21 = 5000.0
# Free_Quantity_1_22 = 0.0
# Free_Quantity_1_23 = 5000.0
# Free_Quantity_1_24 = 5000.0
# Free_Quantity_1_25 = 0.0
# Free_Quantity_1_26 = 5000.0
# Free_Quantity_1_27 = 5000.0
# Free_Quantity_1_28 = 5000.0
# Free_Quantity_1_29 = 0.0
# Free_Quantity_1_3 = 0.0
# Free_Quantity_1_4 = 5000.0
# Free_Quantity_1_5 = 5000.0
# Free_Quantity_1_6 = 0.0
# Free_Quantity_1_7 = 0.0
# Free_Quantity_1_8 = 5000.0
# Free_Quantity_1_9 = 5000.0
# Free_Quantity_2_0 = 0.0
# Free_Quantity_2_1 = 5000.0
# Free_Quantity_2_10 = 0.0
# Free_Quantity_2_11 = 0.0
# Free_Quantity_2_12 = 0.0
# Free_Quantity_2_13 = 5000.0
# Free_Quantity_2_14 = 5000.0
# Free_Quantity_2_15 = 0.0
# Free_Quantity_2_16 = 0.0
# Free_Quantity_2_17 = 0.0
# Free_Quantity_2_18 = 5000.0
# Free_Quantity_2_19 = 5000.0
# Free_Quantity_2_2 = 5000.0
# Free_Quantity_2_20 = 5000.0
# Free_Quantity_2_21 = 5000.0
# Free_Quantity_2_22 = 0.0
# Free_Quantity_2_23 = 0.0
# Free_Quantity_2_24 = 5000.0
# Free_Quantity_2_25 = 0.0
# Free_Quantity_2_26 = 0.0
# Free_Quantity_2_27 = 5000.0
# Free_Quantity_2_28 = 5000.0
# Free_Quantity_2_29 = 0.0
# Free_Quantity_2_3 = 0.0
# Free_Quantity_2_4 = 5000.0
# Free_Quantity_2_5 = 0.0
# Free_Quantity_2_6 = 5000.0
# Free_Quantity_2_7 = 5000.0
# Free_Quantity_2_8 = 5000.0
# Free_Quantity_2_9 = 0.0
# Free_Quantity_3_0 = 5000.0
# Free_Quantity_3_1 = 5000.0
# Free_Quantity_3_10 = 5000.0
# Free_Quantity_3_11 = 0.0
# Free_Quantity_3_12 = 0.0
# Free_Quantity_3_13 = 0.0
# Free_Quantity_3_14 = 0.0
# Free_Quantity_3_15 = 5000.0
# Free_Quantity_3_16 = 5000.0
# Free_Quantity_3_17 = 0.0
# Free_Quantity_3_18 = 5000.0
# Free_Quantity_3_19 = 5000.0
# Free_Quantity_3_2 = 0.0
# Free_Quantity_3_20 = 0.0
# Free_Quantity_3_21 = 0.0
# Free_Quantity_3_22 = 0.0
# Free_Quantity_3_23 = 5000.0
# Free_Quantity_3_24 = 0.0
# Free_Quantity_3_25 = 0.0
# Free_Quantity_3_26 = 5000.0
# Free_Quantity_3_27 = 0.0
# Free_Quantity_3_28 = 0.0
# Free_Quantity_3_29 = 5000.0
# Free_Quantity_3_3 = 0.0
# Free_Quantity_3_4 = 5000.0
# Free_Quantity_3_5 = 5000.0
# Free_Quantity_3_6 = 5000.0
# Free_Quantity_3_7 = 0.0
# Free_Quantity_3_8 = 5000.0
# Free_Quantity_3_9 = 5000.0
# Free_Quantity_4_0 = 5000.0
# Free_Quantity_4_1 = 0.0
# Free_Quantity_4_10 = 0.0
# Free_Quantity_4_11 = 0.0
# Free_Quantity_4_12 = 0.0
# Free_Quantity_4_13 = 0.0
# Free_Quantity_4_14 = 0.0
# Free_Quantity_4_15 = 0.0
# Free_Quantity_4_16 = 5000.0
# Free_Quantity_4_17 = 0.0
# Free_Quantity_4_18 = 5000.0
# Free_Quantity_4_19 = 5000.0
# Free_Quantity_4_2 = 5000.0
# Free_Quantity_4_20 = 0.0
# Free_Quantity_4_21 = 5000.0
# Free_Quantity_4_22 = 0.0
# Free_Quantity_4_23 = 5000.0
# Free_Quantity_4_24 = 5000.0
# Free_Quantity_4_25 = 0.0
# Free_Quantity_4_26 = 5000.0
# Free_Quantity_4_27 = 5000.0
# Free_Quantity_4_28 = 0.0
# Free_Quantity_4_29 = 5000.0
# Free_Quantity_4_3 = 0.0
# Free_Quantity_4_4 = 5000.0
# Free_Quantity_4_5 = 0.0
# Free_Quantity_4_6 = 5000.0
# Free_Quantity_4_7 = 0.0
# Free_Quantity_4_8 = 5000.0
# Free_Quantity_4_9 = 5000.0
# Free_Quantity_5_0 = 5000.0
# Free_Quantity_5_1 = 5000.0
# Free_Quantity_5_10 = 0.0
# Free_Quantity_5_11 = 0.0
# Free_Quantity_5_12 = 5000.0
# Free_Quantity_5_13 = 0.0
# Free_Quantity_5_14 = 0.0
# Free_Quantity_5_15 = 5000.0
# Free_Quantity_5_16 = 5000.0
# Free_Quantity_5_17 = 5000.0
# Free_Quantity_5_18 = 0.0
# Free_Quantity_5_19 = 0.0
# Free_Quantity_5_2 = 5000.0
# Free_Quantity_5_20 = 5000.0
# Free_Quantity_5_21 = 0.0
# Free_Quantity_5_22 = 5000.0
# Free_Quantity_5_23 = 5000.0
# Free_Quantity_5_24 = 0.0
# Free_Quantity_5_25 = 0.0
# Free_Quantity_5_26 = 5000.0
# Free_Quantity_5_27 = 0.0
# Free_Quantity_5_28 = 0.0
# Free_Quantity_5_29 = 5000.0
# Free_Quantity_5_3 = 5000.0
# Free_Quantity_5_4 = 0.0
# Free_Quantity_5_5 = 0.0
# Free_Quantity_5_6 = 5000.0
# Free_Quantity_5_7 = 5000.0
# Free_Quantity_5_8 = 0.0
# Free_Quantity_5_9 = 0.0
# Free_Quantity_6_0 = 5000.0
# Free_Quantity_6_1 = 0.0
# Free_Quantity_6_10 = 5000.0
# Free_Quantity_6_11 = 0.0
# Free_Quantity_6_12 = 5000.0
# Free_Quantity_6_13 = 5000.0
# Free_Quantity_6_14 = 5000.0
# Free_Quantity_6_15 = 5000.0
# Free_Quantity_6_16 = 0.0
# Free_Quantity_6_17 = 5000.0
# Free_Quantity_6_18 = 0.0
# Free_Quantity_6_19 = 0.0
# Free_Quantity_6_2 = 0.0
# Free_Quantity_6_20 = 0.0
# Free_Quantity_6_21 = 0.0
# Free_Quantity_6_22 = 5000.0
# Free_Quantity_6_23 = 0.0
# Free_Quantity_6_24 = 5000.0
# Free_Quantity_6_25 = 0.0
# Free_Quantity_6_26 = 0.0
# Free_Quantity_6_27 = 0.0
# Free_Quantity_6_28 = 5000.0
# Free_Quantity_6_29 = 5000.0
# Free_Quantity_6_3 = 5000.0
# Free_Quantity_6_4 = 0.0
# Free_Quantity_6_5 = 0.0
# Free_Quantity_6_6 = 5000.0
# Free_Quantity_6_7 = 0.0
# Free_Quantity_6_8 = 5000.0
# Free_Quantity_6_9 = 5000.0
# Free_Quantity_7_0 = 5000.0
# Free_Quantity_7_1 = 0.0
# Free_Quantity_7_10 = 5000.0
# Free_Quantity_7_11 = 0.0
# Free_Quantity_7_12 = 0.0
# Free_Quantity_7_13 = 0.0
# Free_Quantity_7_14 = 0.0
# Free_Quantity_7_15 = 0.0
# Free_Quantity_7_16 = 0.0
# Free_Quantity_7_17 = 0.0
# Free_Quantity_7_18 = 5000.0
# Free_Quantity_7_19 = 5000.0
# Free_Quantity_7_2 = 5000.0
# Free_Quantity_7_20 = 5000.0
# Free_Quantity_7_21 = 5000.0
# Free_Quantity_7_22 = 5000.0
# Free_Quantity_7_23 = 5000.0
# Free_Quantity_7_24 = 5000.0
# Free_Quantity_7_25 = 0.0
# Free_Quantity_7_26 = 0.0
# Free_Quantity_7_27 = 0.0
# Free_Quantity_7_28 = 5000.0
# Free_Quantity_7_29 = 0.0
# Free_Quantity_7_3 = 0.0
# Free_Quantity_7_4 = 5000.0
# Free_Quantity_7_5 = 5000.0
# Free_Quantity_7_6 = 5000.0
# Free_Quantity_7_7 = 0.0
# Free_Quantity_7_8 = 5000.0
# Free_Quantity_7_9 = 0.0
# Free_Quantity_8_0 = 5000.0
# Free_Quantity_8_1 = 0.0
# Free_Quantity_8_10 = 0.0
# Free_Quantity_8_11 = 0.0
# Free_Quantity_8_12 = 5000.0
# Free_Quantity_8_13 = 0.0
# Free_Quantity_8_14 = 0.0
# Free_Quantity_8_15 = 5000.0
# Free_Quantity_8_16 = 0.0
# Free_Quantity_8_17 = 5000.0
# Free_Quantity_8_18 = 5000.0
# Free_Quantity_8_19 = 0.0
# Free_Quantity_8_2 = 0.0
# Free_Quantity_8_20 = 0.0
# Free_Quantity_8_21 = 5000.0
# Free_Quantity_8_22 = 0.0
# Free_Quantity_8_23 = 5000.0
# Free_Quantity_8_24 = 5000.0
# Free_Quantity_8_25 = 0.0
# Free_Quantity_8_26 = 5000.0
# Free_Quantity_8_27 = 5000.0
# Free_Quantity_8_28 = 5000.0
# Free_Quantity_8_29 = 0.0
# Free_Quantity_8_3 = 5000.0
# Free_Quantity_8_4 = 5000.0
# Free_Quantity_8_5 = 5000.0
# Free_Quantity_8_6 = 0.0
# Free_Quantity_8_7 = 5000.0
# Free_Quantity_8_8 = 0.0
# Free_Quantity_8_9 = 0.0
# Free_Quantity_9_0 = 5000.0
# Free_Quantity_9_1 = 5000.0
# Free_Quantity_9_10 = 5000.0
# Free_Quantity_9_11 = 0.0
# Free_Quantity_9_12 = 0.0
# Free_Quantity_9_13 = 5000.0
# Free_Quantity_9_14 = 0.0
# Free_Quantity_9_15 = 5000.0
# Free_Quantity_9_16 = 0.0
# Free_Quantity_9_17 = 0.0
# Free_Quantity_9_18 = 5000.0
# Free_Quantity_9_19 = 0.0
# Free_Quantity_9_2 = 5000.0
# Free_Quantity_9_20 = 5000.0
# Free_Quantity_9_21 = 5000.0
# Free_Quantity_9_22 = 0.0
# Free_Quantity_9_23 = 5000.0
# Free_Quantity_9_24 = 5000.0
# Free_Quantity_9_25 = 0.0
# Free_Quantity_9_26 = 5000.0
# Free_Quantity_9_27 = 0.0
# Free_Quantity_9_28 = 5000.0
# Free_Quantity_9_29 = 5000.0
# Free_Quantity_9_3 = 0.0
# Free_Quantity_9_4 = 0.0
# Free_Quantity_9_5 = 0.0
# Free_Quantity_9_6 = 0.0
# Free_Quantity_9_7 = 0.0
# Free_Quantity_9_8 = 5000.0
# Free_Quantity_9_9 = 0.0
# IsPromoted_0_0 = 0.0
# IsPromoted_0_1 = 0.0
# IsPromoted_0_10 = 1.0
# IsPromoted_0_11 = 0.0
# IsPromoted_0_12 = 1.0
# IsPromoted_0_13 = 0.0
# IsPromoted_0_14 = 0.0
# IsPromoted_0_15 = 0.0
# IsPromoted_0_16 = 0.0
# IsPromoted_0_17 = 1.0
# IsPromoted_0_18 = 1.0
# IsPromoted_0_19 = 0.0
# IsPromoted_0_2 = 0.0
# IsPromoted_0_20 = 1.0
# IsPromoted_0_21 = 1.0
# IsPromoted_0_22 = 0.0
# IsPromoted_0_23 = 0.0
# IsPromoted_0_24 = 0.0
# IsPromoted_0_25 = 1.0
# IsPromoted_0_26 = 0.0
# IsPromoted_0_27 = 0.0
# IsPromoted_0_28 = 0.0
# IsPromoted_0_29 = 0.0
# IsPromoted_0_3 = 0.0
# IsPromoted_0_4 = 0.0
# IsPromoted_0_5 = 1.0
# IsPromoted_0_6 = 1.0
# IsPromoted_0_7 = 1.0
# IsPromoted_0_8 = 0.0
# IsPromoted_0_9 = 0.0
# IsPromoted_1_0 = 1.0
# IsPromoted_1_1 = 0.0
# IsPromoted_1_10 = 0.0
# IsPromoted_1_11 = 0.0
# IsPromoted_1_12 = 0.0
# IsPromoted_1_13 = 0.0
# IsPromoted_1_14 = 0.0
# IsPromoted_1_15 = 0.0
# IsPromoted_1_16 = 1.0
# IsPromoted_1_17 = 1.0
# IsPromoted_1_18 = 1.0
# IsPromoted_1_19 = 1.0
# IsPromoted_1_2 = 0.0
# IsPromoted_1_20 = 0.0
# IsPromoted_1_21 = 1.0
# IsPromoted_1_22 = 0.0
# IsPromoted_1_23 = 1.0
# IsPromoted_1_24 = 1.0
# IsPromoted_1_25 = 0.0
# IsPromoted_1_26 = 1.0
# IsPromoted_1_27 = 1.0
# IsPromoted_1_28 = 1.0
# IsPromoted_1_29 = 0.0
# IsPromoted_1_3 = 0.0
# IsPromoted_1_4 = 1.0
# IsPromoted_1_5 = 1.0
# IsPromoted_1_6 = 0.0
# IsPromoted_1_7 = 0.0
# IsPromoted_1_8 = 1.0
# IsPromoted_1_9 = 1.0
# IsPromoted_2_0 = 0.0
# IsPromoted_2_1 = 1.0
# IsPromoted_2_10 = 0.0
# IsPromoted_2_11 = 0.0
# IsPromoted_2_12 = 0.0
# IsPromoted_2_13 = 1.0
# IsPromoted_2_14 = 1.0
# IsPromoted_2_15 = 0.0
# IsPromoted_2_16 = 0.0
# IsPromoted_2_17 = 0.0
# IsPromoted_2_18 = 1.0
# IsPromoted_2_19 = 1.0
# IsPromoted_2_2 = 1.0
# IsPromoted_2_20 = 1.0
# IsPromoted_2_21 = 1.0
# IsPromoted_2_22 = 0.0
# IsPromoted_2_23 = 0.0
# IsPromoted_2_24 = 1.0
# IsPromoted_2_25 = 0.0
# IsPromoted_2_26 = 0.0
# IsPromoted_2_27 = 1.0
# IsPromoted_2_28 = 1.0
# IsPromoted_2_29 = 0.0
# IsPromoted_2_3 = 0.0
# IsPromoted_2_4 = 1.0
# IsPromoted_2_5 = 0.0
# IsPromoted_2_6 = 1.0
# IsPromoted_2_7 = 1.0
# IsPromoted_2_8 = 1.0
# IsPromoted_2_9 = 0.0
# IsPromoted_3_0 = 1.0
# IsPromoted_3_1 = 1.0
# IsPromoted_3_10 = 1.0
# IsPromoted_3_11 = 0.0
# IsPromoted_3_12 = 0.0
# IsPromoted_3_13 = 0.0
# IsPromoted_3_14 = 0.0
# IsPromoted_3_15 = 1.0
# IsPromoted_3_16 = 1.0
# IsPromoted_3_17 = 0.0
# IsPromoted_3_18 = 1.0
# IsPromoted_3_19 = 1.0
# IsPromoted_3_2 = 0.0
# IsPromoted_3_20 = 0.0
# IsPromoted_3_21 = 0.0
# IsPromoted_3_22 = 0.0
# IsPromoted_3_23 = 1.0
# IsPromoted_3_24 = 0.0
# IsPromoted_3_25 = 0.0
# IsPromoted_3_26 = 1.0
# IsPromoted_3_27 = 0.0
# IsPromoted_3_28 = 0.0
# IsPromoted_3_29 = 1.0
# IsPromoted_3_3 = 0.0
# IsPromoted_3_4 = 1.0
# IsPromoted_3_5 = 1.0
# IsPromoted_3_6 = 1.0
# IsPromoted_3_7 = 0.0
# IsPromoted_3_8 = 1.0
# IsPromoted_3_9 = 1.0
# IsPromoted_4_0 = 1.0
# IsPromoted_4_1 = 0.0
# IsPromoted_4_10 = 0.0
# IsPromoted_4_11 = 0.0
# IsPromoted_4_12 = 0.0
# IsPromoted_4_13 = 0.0
# IsPromoted_4_14 = 0.0
# IsPromoted_4_15 = 0.0
# IsPromoted_4_16 = 1.0
# IsPromoted_4_17 = 0.0
# IsPromoted_4_18 = 1.0
# IsPromoted_4_19 = 1.0
# IsPromoted_4_2 = 1.0
# IsPromoted_4_20 = 0.0
# IsPromoted_4_21 = 1.0
# IsPromoted_4_22 = 0.0
# IsPromoted_4_23 = 1.0
# IsPromoted_4_24 = 1.0
# IsPromoted_4_25 = 0.0
# IsPromoted_4_26 = 1.0
# IsPromoted_4_27 = 1.0
# IsPromoted_4_28 = 0.0
# IsPromoted_4_29 = 1.0
# IsPromoted_4_3 = 0.0
# IsPromoted_4_4 = 1.0
# IsPromoted_4_5 = 0.0
# IsPromoted_4_6 = 1.0
# IsPromoted_4_7 = 0.0
# IsPromoted_4_8 = 1.0
# IsPromoted_4_9 = 1.0
# IsPromoted_5_0 = 1.0
# IsPromoted_5_1 = 1.0
# IsPromoted_5_10 = 0.0
# IsPromoted_5_11 = 0.0
# IsPromoted_5_12 = 1.0
# IsPromoted_5_13 = 0.0
# IsPromoted_5_14 = 0.0
# IsPromoted_5_15 = 1.0
# IsPromoted_5_16 = 1.0
# IsPromoted_5_17 = 1.0
# IsPromoted_5_18 = 0.0
# IsPromoted_5_19 = 0.0
# IsPromoted_5_2 = 1.0
# IsPromoted_5_20 = 1.0
# IsPromoted_5_21 = 0.0
# IsPromoted_5_22 = 1.0
# IsPromoted_5_23 = 1.0
# IsPromoted_5_24 = 0.0
# IsPromoted_5_25 = 0.0
# IsPromoted_5_26 = 1.0
# IsPromoted_5_27 = 0.0
# IsPromoted_5_28 = 0.0
# IsPromoted_5_29 = 1.0
# IsPromoted_5_3 = 1.0
# IsPromoted_5_4 = 0.0
# IsPromoted_5_5 = 0.0
# IsPromoted_5_6 = 1.0
# IsPromoted_5_7 = 1.0
# IsPromoted_5_8 = 0.0
# IsPromoted_5_9 = 0.0
# IsPromoted_6_0 = 1.0
# IsPromoted_6_1 = 0.0
# IsPromoted_6_10 = 1.0
# IsPromoted_6_11 = 0.0
# IsPromoted_6_12 = 1.0
# IsPromoted_6_13 = 1.0
# IsPromoted_6_14 = 1.0
# IsPromoted_6_15 = 1.0
# IsPromoted_6_16 = 0.0
# IsPromoted_6_17 = 1.0
# IsPromoted_6_18 = 0.0
# IsPromoted_6_19 = 0.0
# IsPromoted_6_2 = 0.0
# IsPromoted_6_20 = 0.0
# IsPromoted_6_21 = 0.0
# IsPromoted_6_22 = 1.0
# IsPromoted_6_23 = 0.0
# IsPromoted_6_24 = 1.0
# IsPromoted_6_25 = 0.0
# IsPromoted_6_26 = 0.0
# IsPromoted_6_27 = 0.0
# IsPromoted_6_28 = 1.0
# IsPromoted_6_29 = 1.0
# IsPromoted_6_3 = 1.0
# IsPromoted_6_4 = 0.0
# IsPromoted_6_5 = 0.0
# IsPromoted_6_6 = 1.0
# IsPromoted_6_7 = 0.0
# IsPromoted_6_8 = 1.0
# IsPromoted_6_9 = 1.0
# IsPromoted_7_0 = 1.0
# IsPromoted_7_1 = 0.0
# IsPromoted_7_10 = 1.0
# IsPromoted_7_11 = 0.0
# IsPromoted_7_12 = 0.0
# IsPromoted_7_13 = 0.0
# IsPromoted_7_14 = 0.0
# IsPromoted_7_15 = 0.0
# IsPromoted_7_16 = 0.0
# IsPromoted_7_17 = 0.0
# IsPromoted_7_18 = 1.0
# IsPromoted_7_19 = 1.0
# IsPromoted_7_2 = 1.0
# IsPromoted_7_20 = 1.0
# IsPromoted_7_21 = 1.0
# IsPromoted_7_22 = 1.0
# IsPromoted_7_23 = 1.0
# IsPromoted_7_24 = 1.0
# IsPromoted_7_25 = 0.0
# IsPromoted_7_26 = 0.0
# IsPromoted_7_27 = 0.0
# IsPromoted_7_28 = 1.0
# IsPromoted_7_29 = 0.0
# IsPromoted_7_3 = 0.0
# IsPromoted_7_4 = 1.0
# IsPromoted_7_5 = 1.0
# IsPromoted_7_6 = 1.0
# IsPromoted_7_7 = 0.0
# IsPromoted_7_8 = 1.0
# IsPromoted_7_9 = 0.0
# IsPromoted_8_0 = 1.0
# IsPromoted_8_1 = 0.0
# IsPromoted_8_10 = 0.0
# IsPromoted_8_11 = 0.0
# IsPromoted_8_12 = 1.0
# IsPromoted_8_13 = 0.0
# IsPromoted_8_14 = 0.0
# IsPromoted_8_15 = 1.0
# IsPromoted_8_16 = 0.0
# IsPromoted_8_17 = 1.0
# IsPromoted_8_18 = 1.0
# IsPromoted_8_19 = 0.0
# IsPromoted_8_2 = 0.0
# IsPromoted_8_20 = 0.0
# IsPromoted_8_21 = 1.0
# IsPromoted_8_22 = 0.0
# IsPromoted_8_23 = 1.0
# IsPromoted_8_24 = 1.0
# IsPromoted_8_25 = 0.0
# IsPromoted_8_26 = 1.0
# IsPromoted_8_27 = 1.0
# IsPromoted_8_28 = 1.0
# IsPromoted_8_29 = 0.0
# IsPromoted_8_3 = 1.0
# IsPromoted_8_4 = 1.0
# IsPromoted_8_5 = 1.0
# IsPromoted_8_6 = 0.0
# IsPromoted_8_7 = 1.0
# IsPromoted_8_8 = 0.0
# IsPromoted_8_9 = 0.0
# IsPromoted_9_0 = 1.0
# IsPromoted_9_1 = 1.0
# IsPromoted_9_10 = 1.0
# IsPromoted_9_11 = 0.0
# IsPromoted_9_12 = 0.0
# IsPromoted_9_13 = 1.0
# IsPromoted_9_14 = 0.0
# IsPromoted_9_15 = 1.0
# IsPromoted_9_16 = 0.0
# IsPromoted_9_17 = 0.0
# IsPromoted_9_18 = 1.0
# IsPromoted_9_19 = 0.0
# IsPromoted_9_2 = 1.0
# IsPromoted_9_20 = 1.0
# IsPromoted_9_21 = 1.0
# IsPromoted_9_22 = 0.0
# IsPromoted_9_23 = 1.0
# IsPromoted_9_24 = 1.0
# IsPromoted_9_25 = 0.0
# IsPromoted_9_26 = 1.0
# IsPromoted_9_27 = 0.0
# IsPromoted_9_28 = 1.0
# IsPromoted_9_29 = 1.0
# IsPromoted_9_3 = 0.0
# IsPromoted_9_4 = 0.0
# IsPromoted_9_5 = 0.0
# IsPromoted_9_6 = 0.0
# IsPromoted_9_7 = 0.0
# IsPromoted_9_8 = 1.0
# IsPromoted_9_9 = 0.0
# Paid_Quantity_0_0 = 5782.0
# Paid_Quantity_0_1 = 5357.0
# Paid_Quantity_0_10 = 4875.0
# Paid_Quantity_0_11 = 5173.0
# Paid_Quantity_0_12 = 4769.0
# Paid_Quantity_0_13 = 5336.0
# Paid_Quantity_0_14 = 4849.0
# Paid_Quantity_0_15 = 4797.0
# Paid_Quantity_0_16 = 5532.0
# Paid_Quantity_0_17 = 4096.0
# Paid_Quantity_0_18 = 5456.0
# Paid_Quantity_0_19 = 5414.0
# Paid_Quantity_0_2 = 5065.0
# Paid_Quantity_0_20 = 4463.0
# Paid_Quantity_0_21 = 5389.0
# Paid_Quantity_0_22 = 5689.0
# Paid_Quantity_0_23 = 5057.0
# Paid_Quantity_0_24 = 4831.0
# Paid_Quantity_0_25 = 4830.0
# Paid_Quantity_0_26 = 5013.0
# Paid_Quantity_0_27 = 5192.0
# Paid_Quantity_0_28 = 5634.0
# Paid_Quantity_0_29 = 4610.0
# Paid_Quantity_0_3 = 5407.0
# Paid_Quantity_0_4 = 4391.0
# Paid_Quantity_0_5 = 4159.0
# Paid_Quantity_0_6 = 5379.0
# Paid_Quantity_0_7 = 4291.0
# Paid_Quantity_0_8 = 4595.0
# Paid_Quantity_0_9 = 4911.0
# Paid_Quantity_1_0 = 38960.0
# Paid_Quantity_1_1 = 4999.0
# Paid_Quantity_1_10 = 5922.0
# Paid_Quantity_1_11 = 4133.0
# Paid_Quantity_1_12 = 4809.0
# Paid_Quantity_1_13 = 5079.0
# Paid_Quantity_1_14 = 4371.0
# Paid_Quantity_1_15 = 4326.0
# Paid_Quantity_1_16 = 39720.0
# Paid_Quantity_1_17 = 39750.0
# Paid_Quantity_1_18 = 40450.0
# Paid_Quantity_1_19 = 40699.0
# Paid_Quantity_1_2 = 4821.0
# Paid_Quantity_1_20 = 4412.0
# Paid_Quantity_1_21 = 40210.0
# Paid_Quantity_1_22 = 5623.0
# Paid_Quantity_1_23 = 40606.0
# Paid_Quantity_1_24 = 38863.0
# Paid_Quantity_1_25 = 4179.0
# Paid_Quantity_1_26 = 38796.0
# Paid_Quantity_1_27 = 40376.0
# Paid_Quantity_1_28 = 40491.0
# Paid_Quantity_1_29 = 4541.0
# Paid_Quantity_1_3 = 5138.0
# Paid_Quantity_1_4 = 40322.0
# Paid_Quantity_1_5 = 40201.0
# Paid_Quantity_1_6 = 4987.0
# Paid_Quantity_1_7 = 4941.0
# Paid_Quantity_1_8 = 40577.0
# Paid_Quantity_1_9 = 38819.0
# Paid_Quantity_2_0 = 4492.0
# Paid_Quantity_2_1 = 32032.0
# Paid_Quantity_2_10 = 4368.0
# Paid_Quantity_2_11 = 5576.0
# Paid_Quantity_2_12 = 4746.0
# Paid_Quantity_2_13 = 32462.0
# Paid_Quantity_2_14 = 32274.0
# Paid_Quantity_2_15 = 4845.0
# Paid_Quantity_2_16 = 5918.0
# Paid_Quantity_2_17 = 5214.0
# Paid_Quantity_2_18 = 31288.0
# Paid_Quantity_2_19 = 32329.0
# Paid_Quantity_2_2 = 32360.0
# Paid_Quantity_2_20 = 32324.0
# Paid_Quantity_2_21 = 31590.0
# Paid_Quantity_2_22 = 5566.0
# Paid_Quantity_2_23 = 5602.0
# Paid_Quantity_2_24 = 31657.0
# Paid_Quantity_2_25 = 4198.0
# Paid_Quantity_2_26 = 4031.0
# Paid_Quantity_2_27 = 31848.0
# Paid_Quantity_2_28 = 30779.0
# Paid_Quantity_2_29 = 5126.0
# Paid_Quantity_2_3 = 4973.0
# Paid_Quantity_2_4 = 31207.0
# Paid_Quantity_2_5 = 4652.0
# Paid_Quantity_2_6 = 31453.0
# Paid_Quantity_2_7 = 30941.0
# Paid_Quantity_2_8 = 32522.0
# Paid_Quantity_2_9 = 5586.0
# Paid_Quantity_3_0 = 36285.0
# Paid_Quantity_3_1 = 37059.0
# Paid_Quantity_3_10 = 35819.0
# Paid_Quantity_3_11 = 4013.0
# Paid_Quantity_3_12 = 4658.0
# Paid_Quantity_3_13 = 4933.0
# Paid_Quantity_3_14 = 4862.0
# Paid_Quantity_3_15 = 36934.0
# Paid_Quantity_3_16 = 37060.0
# Paid_Quantity_3_17 = 4644.0
# Paid_Quantity_3_18 = 36882.0
# Paid_Quantity_3_19 = 36213.0
# Paid_Quantity_3_2 = 4867.0
# Paid_Quantity_3_20 = 4377.0
# Paid_Quantity_3_21 = 4714.0
# Paid_Quantity_3_22 = 4122.0
# Paid_Quantity_3_23 = 36952.0
# Paid_Quantity_3_24 = 4641.0
# Paid_Quantity_3_25 = 4240.0
# Paid_Quantity_3_26 = 35425.0
# Paid_Quantity_3_27 = 4387.0
# Paid_Quantity_3_28 = 4650.0
# Paid_Quantity_3_29 = 35698.0
# Paid_Quantity_3_3 = 4728.0
# Paid_Quantity_3_4 = 35778.0
# Paid_Quantity_3_5 = 36180.0
# Paid_Quantity_3_6 = 36926.0
# Paid_Quantity_3_7 = 5648.0
# Paid_Quantity_3_8 = 35687.0
# Paid_Quantity_3_9 = 36864.0
# Paid_Quantity_4_0 = 42737.0
# Paid_Quantity_4_1 = 4185.0
# Paid_Quantity_4_10 = 4542.0
# Paid_Quantity_4_11 = 4470.0
# Paid_Quantity_4_12 = 5379.0
# Paid_Quantity_4_13 = 4773.0
# Paid_Quantity_4_14 = 5181.0
# Paid_Quantity_4_15 = 4975.0
# Paid_Quantity_4_16 = 42896.0
# Paid_Quantity_4_17 = 4517.0
# Paid_Quantity_4_18 = 43377.0
# Paid_Quantity_4_19 = 43342.0
# Paid_Quantity_4_2 = 43950.0
# Paid_Quantity_4_20 = 4408.0
# Paid_Quantity_4_21 = 42293.0
# Paid_Quantity_4_22 = 4803.0
# Paid_Quantity_4_23 = 42551.0
# Paid_Quantity_4_24 = 43972.0
# Paid_Quantity_4_25 = 5118.0
# Paid_Quantity_4_26 = 43327.0
# Paid_Quantity_4_27 = 42319.0
# Paid_Quantity_4_28 = 4756.0
# Paid_Quantity_4_29 = 44144.0
# Paid_Quantity_4_3 = 4275.0
# Paid_Quantity_4_4 = 44013.0
# Paid_Quantity_4_5 = 4235.0
# Paid_Quantity_4_6 = 43315.0
# Paid_Quantity_4_7 = 4502.0
# Paid_Quantity_4_8 = 43709.0
# Paid_Quantity_4_9 = 43387.0
# Paid_Quantity_5_0 = 33985.0
# Paid_Quantity_5_1 = 34408.0
# Paid_Quantity_5_10 = 5163.0
# Paid_Quantity_5_11 = 5150.0
# Paid_Quantity_5_12 = 35063.0
# Paid_Quantity_5_13 = 4799.0
# Paid_Quantity_5_14 = 4043.0
# Paid_Quantity_5_15 = 33928.0
# Paid_Quantity_5_16 = 35567.0
# Paid_Quantity_5_17 = 34262.0
# Paid_Quantity_5_18 = 5679.0
# Paid_Quantity_5_19 = 4244.0
# Paid_Quantity_5_2 = 34160.0
# Paid_Quantity_5_20 = 34319.0
# Paid_Quantity_5_21 = 5500.0
# Paid_Quantity_5_22 = 35201.0
# Paid_Quantity_5_23 = 35455.0
# Paid_Quantity_5_24 = 5935.0
# Paid_Quantity_5_25 = 4763.0
# Paid_Quantity_5_26 = 33972.0
# Paid_Quantity_5_27 = 4782.0
# Paid_Quantity_5_28 = 5766.0
# Paid_Quantity_5_29 = 34156.0
# Paid_Quantity_5_3 = 33925.0
# Paid_Quantity_5_4 = 5170.0
# Paid_Quantity_5_5 = 5090.0
# Paid_Quantity_5_6 = 35716.0
# Paid_Quantity_5_7 = 34611.0
# Paid_Quantity_5_8 = 5907.0
# Paid_Quantity_5_9 = 5943.0
# Paid_Quantity_6_0 = 38441.0
# Paid_Quantity_6_1 = 5085.0
# Paid_Quantity_6_10 = 39127.0
# Paid_Quantity_6_11 = 5647.0
# Paid_Quantity_6_12 = 38521.0
# Paid_Quantity_6_13 = 37966.0
# Paid_Quantity_6_14 = 39691.0
# Paid_Quantity_6_15 = 37850.0
# Paid_Quantity_6_16 = 4913.0
# Paid_Quantity_6_17 = 39230.0
# Paid_Quantity_6_18 = 4743.0
# Paid_Quantity_6_19 = 4746.0
# Paid_Quantity_6_2 = 5219.0
# Paid_Quantity_6_20 = 4744.0
# Paid_Quantity_6_21 = 4633.0
# Paid_Quantity_6_22 = 39125.0
# Paid_Quantity_6_23 = 4788.0
# Paid_Quantity_6_24 = 38841.0
# Paid_Quantity_6_25 = 5398.0
# Paid_Quantity_6_26 = 5279.0
# Paid_Quantity_6_27 = 4079.0
# Paid_Quantity_6_28 = 39177.0
# Paid_Quantity_6_29 = 39597.0
# Paid_Quantity_6_3 = 39569.0
# Paid_Quantity_6_4 = 4754.0
# Paid_Quantity_6_5 = 4801.0
# Paid_Quantity_6_6 = 39113.0
# Paid_Quantity_6_7 = 4811.0
# Paid_Quantity_6_8 = 38481.0
# Paid_Quantity_6_9 = 38406.0
# Paid_Quantity_7_0 = 48208.0
# Paid_Quantity_7_1 = 5617.0
# Paid_Quantity_7_10 = 48404.0
# Paid_Quantity_7_11 = 5140.0
# Paid_Quantity_7_12 = 5074.0
# Paid_Quantity_7_13 = 5558.0
# Paid_Quantity_7_14 = 4344.0
# Paid_Quantity_7_15 = 4460.0
# Paid_Quantity_7_16 = 5867.0
# Paid_Quantity_7_17 = 5052.0
# Paid_Quantity_7_18 = 48867.0
# Paid_Quantity_7_19 = 47777.0
# Paid_Quantity_7_2 = 47944.0
# Paid_Quantity_7_20 = 47681.0
# Paid_Quantity_7_21 = 47859.0
# Paid_Quantity_7_22 = 48102.0
# Paid_Quantity_7_23 = 49281.0
# Paid_Quantity_7_24 = 48983.0
# Paid_Quantity_7_25 = 5504.0
# Paid_Quantity_7_26 = 5450.0
# Paid_Quantity_7_27 = 5848.0
# Paid_Quantity_7_28 = 47982.0
# Paid_Quantity_7_29 = 4974.0
# Paid_Quantity_7_3 = 5737.0
# Paid_Quantity_7_4 = 47841.0
# Paid_Quantity_7_5 = 48058.0
# Paid_Quantity_7_6 = 48521.0
# Paid_Quantity_7_7 = 5645.0
# Paid_Quantity_7_8 = 49649.0
# Paid_Quantity_7_9 = 5546.0
# Paid_Quantity_8_0 = 44787.0
# Paid_Quantity_8_1 = 4969.0
# Paid_Quantity_8_10 = 4002.0
# Paid_Quantity_8_11 = 5526.0
# Paid_Quantity_8_12 = 44038.0
# Paid_Quantity_8_13 = 5645.0
# Paid_Quantity_8_14 = 4893.0
# Paid_Quantity_8_15 = 44911.0
# Paid_Quantity_8_16 = 4715.0
# Paid_Quantity_8_17 = 44921.0
# Paid_Quantity_8_18 = 45186.0
# Paid_Quantity_8_19 = 5142.0
# Paid_Quantity_8_2 = 5765.0
# Paid_Quantity_8_20 = 5115.0
# Paid_Quantity_8_21 = 45590.0
# Paid_Quantity_8_22 = 5601.0
# Paid_Quantity_8_23 = 44455.0
# Paid_Quantity_8_24 = 44412.0
# Paid_Quantity_8_25 = 5022.0
# Paid_Quantity_8_26 = 45949.0
# Paid_Quantity_8_27 = 45370.0
# Paid_Quantity_8_28 = 44464.0
# Paid_Quantity_8_29 = 5838.0
# Paid_Quantity_8_3 = 45169.0
# Paid_Quantity_8_4 = 44386.0
# Paid_Quantity_8_5 = 44799.0
# Paid_Quantity_8_6 = 4989.0
# Paid_Quantity_8_7 = 44464.0
# Paid_Quantity_8_8 = 5580.0
# Paid_Quantity_8_9 = 5516.0
# Paid_Quantity_9_0 = 49307.0
# Paid_Quantity_9_1 = 49110.0
# Paid_Quantity_9_10 = 50597.0
# Paid_Quantity_9_11 = 4505.0
# Paid_Quantity_9_12 = 4366.0
# Paid_Quantity_9_13 = 50788.0
# Paid_Quantity_9_14 = 5904.0
# Paid_Quantity_9_15 = 50207.0
# Paid_Quantity_9_16 = 5937.0
# Paid_Quantity_9_17 = 5868.0
# Paid_Quantity_9_18 = 49337.0
# Paid_Quantity_9_19 = 4599.0
# Paid_Quantity_9_2 = 49802.0
# Paid_Quantity_9_20 = 49715.0
# Paid_Quantity_9_21 = 49852.0
# Paid_Quantity_9_22 = 5709.0
# Paid_Quantity_9_23 = 49498.0
# Paid_Quantity_9_24 = 49608.0
# Paid_Quantity_9_25 = 5970.0
# Paid_Quantity_9_26 = 50590.0
# Paid_Quantity_9_27 = 5704.0
# Paid_Quantity_9_28 = 49146.0
# Paid_Quantity_9_29 = 49060.0
# Paid_Quantity_9_3 = 5284.0
# Paid_Quantity_9_4 = 4996.0
# Paid_Quantity_9_5 = 4416.0
# Paid_Quantity_9_6 = 4643.0
# Paid_Quantity_9_7 = 4398.0
# Paid_Quantity_9_8 = 49957.0
# Paid_Quantity_9_9 = 5705.0

# %%
#PROMO RATIO IS CALCULATED BASED ON THE OPTIMUM P[i][t] AND F[i][t] VALUES
Promo_Ratio = np.zeros((I, T), dtype = float)

for i in Products:
    for t in PHorizon:
        Promo_Ratio[i][t] = (F[i][t].varValue)/(P[i][t].varValue + F[i][t].varValue)

df_Promo_Ratio = pd.DataFrame(Promo_Ratio,
                 index=range(1,I+1),
                 columns=range(1,T+1))
df_Promo_Ratio
# Out:
#           1         2         3         4         5         6         7   \
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000240  0.000186
# 2   0.113740  0.000000  0.000000  0.000000  0.110322  0.110617  0.000000
# 3   0.000000  0.135018  0.133833  0.000000  0.138095  0.000000  0.137163
# 4   0.121109  0.118881  0.000000  0.000000  0.122615  0.121418  0.119258
# 5   0.104741  0.000000  0.102145  0.000000  0.102014  0.000000  0.103488
# 6   0.128254  0.126878  0.127681  0.128452  0.000000  0.000000  0.122802
# 7   0.115099  0.000000  0.000000  0.112186  0.000000  0.000000  0.113345
# 8   0.093971  0.000000  0.094439  0.000000  0.094623  0.094236  0.093421
# 9   0.100428  0.000000  0.000000  0.099663  0.101243  0.100404  0.000000
# 10  0.092069  0.092404  0.091238  0.000000  0.000000  0.000000  0.000000
#
#           8         9         10  ...        21        22        23        24  \
# 1   0.000233  0.000000  0.000000  ...  0.000224  0.000186  0.000000  0.000000
# 2   0.000000  0.109704  0.114106  ...  0.000000  0.110595  0.000000  0.109635
# 3   0.139117  0.133255  0.000000  ...  0.133962  0.136649  0.000000  0.000000
# 4   0.000000  0.122889  0.119434  ...  0.000000  0.000000  0.000000  0.119184
# 5   0.000000  0.102650  0.103334  ...  0.000000  0.105724  0.000000  0.105150
# 6   0.126228  0.000000  0.000000  ...  0.127165  0.000000  0.124375  0.123594
# 7   0.000000  0.114993  0.115191  ...  0.000000  0.000000  0.113314  0.000000
# 8   0.000000  0.091493  0.000000  ...  0.094911  0.094591  0.094158  0.092113
# 9   0.101084  0.000000  0.000000  ...  0.000000  0.098834  0.000000  0.101102
# 10  0.000000  0.090980  0.000000  ...  0.091383  0.091154  0.000000  0.091746
#
#           25        26        27        28        29        30
# 1   0.000000  0.000207  0.000000  0.000000  0.000000  0.000000
# 2   0.113991  0.000000  0.114166  0.110190  0.109912  0.000000
# 3   0.136400  0.000000  0.000000  0.135693  0.139747  0.000000
# 4   0.000000  0.000000  0.123686  0.000000  0.000000  0.122856
# 5   0.102099  0.000000  0.103462  0.105666  0.000000  0.101742
# 6   0.000000  0.000000  0.128297  0.000000  0.000000  0.127694
# 7   0.114048  0.000000  0.000000  0.000000  0.113181  0.112115
# 8   0.092622  0.000000  0.000000  0.000000  0.094372  0.000000
# 9   0.101190  0.000000  0.098137  0.099265  0.101084  0.000000
# 10  0.091562  0.000000  0.089944  0.000000  0.092343  0.092490
#
# [10 rows x 30 columns]

# %%
Promo_Sensitivity
# Out:
# array([ 1.        ,  7.9533866 ,  6.35054765,  7.24450098,  8.64909589,
#         6.96332305,  7.74080694,  9.7351889 ,  9.00555674, 10.        ])
