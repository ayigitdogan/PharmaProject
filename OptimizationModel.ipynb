# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import seaborn as sns
from matplotlib import style
import math
import random

# %%
#LP MAXIMIZATION MODEL

from pulp import *
Promo_Model = LpProblem("Pharma_Promotion_Model", LpMaximize)

# %%
#PARAMETERS

T=30 # end of promotion horizon
PHorizon = list(range(0, T))

I=10 # product count 
Products = list(range(0, I))

#NOT USED RIGHT NOW
Promo_Levels = [0,1,2]

Base_Demand = np.zeros((I, T), dtype = int)

for i in Products:
    for t in PHorizon:
        Base_Demand[i][t] = random.randint(0, 10000)
    
Promo_Sensitivity = np.zeros(I, dtype = float)
for i in Products:
    Promo_Sensitivity[i] = random.uniform(1,2)


Total_PaidQty_Limit = 1000000
Total_FreeQty_Limit = 250000

Promo_Sensitivity
# Out:
# array([1.19488356, 1.13720047, 1.65060048, 1.17997442, 1.65451094,
#        1.76058517, 1.73279655, 1.88830118, 1.25199053, 1.36807305])

# %%
#DECISION VARIABLES

#Paid Quantity
PaidQtyLimit = 20000
P = LpVariable.dicts("Paid_Quantity",(Products,PHorizon),lowBound=0, upBound=PaidQtyLimit, cat='Integer')

#Free Quantity
FreeQtyLimit = 5000
F = LpVariable.dicts("Free_Quantity",(Products,PHorizon),lowBound=0, upBound=FreeQtyLimit, cat='Integer')

#Is Product "i" at Time "t" Promoted?
X = LpVariable.dicts("IsPromoted",(Products,PHorizon),cat='Binary')

#Promo Ratio
#R = LpVariable.dicts("Promo_Ratio",(Products,PHorizon),lowBound=0, upBound=1, cat='Continuous')

# %%
#OBJECTIVE FUNCTION

Total_Paid_Quantity = lpSum(lpSum(P[i][t] for i in Products) for t in PHorizon)

Promo_Model += Total_Paid_Quantity

# %%
#DEMAND SATISFACTION
for i in Products:
    for t in PHorizon:
        Promo_Model += P[i][t] + F[i][t] <= Base_Demand[i][t]*(1 + Promo_Sensitivity[i]*F[i][t]*(1/Base_Demand[i][t]))

#NO FREE QTY WITHOUT PROMOTION
M = FreeQtyLimit
for i in Products:
    for t in PHorizon:
        Promo_Model += F[i][t] <= X[i][t]*M
        Promo_Model += F[i][t] >= X[i][t]-0.5

#PROMOTED PRODUCTS AT TIME "t"
Promoted_Products = 8
for t in PHorizon:
    Promo_Model += lpSum(X[i][t] for i in Products) <= Promoted_Products
    
#PROMO PERIOD FOR PRODUCT "i"  
Max_Promo_Duration = 25
Min_Promo_Duration = 15
for i in Products:
    Promo_Model += lpSum(X[i][t] for t in PHorizon) <= Max_Promo_Duration
    Promo_Model += lpSum(X[i][t] for t in PHorizon) >= Min_Promo_Duration

#TOTAL PAID QUANTITY PER PRODUCT
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(P[i][t] for t in PHorizon) <= Total_PaidQty_Limit
    
#TOTAL FREE QUANTITY PER PRODUCT
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(F[i][t] for t in PHorizon) <= Total_FreeQty_Limit

# %%
solver = GUROBI()
solver.solve(Promo_Model)

# The status of the solution is printed to the screen
print("Status:", LpStatus[Promo_Model.status])
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (mac64[arm] - Darwin 22.3.0 22D68)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1550 rows, 900 columns and 20700 nonzeros
# Model fingerprint: 0xd9125825
# Variable types: 0 continuous, 900 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-01, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+04]
#   RHS range        [5e-01, 1e+06]
# Found heuristic solution: objective 1476103.0000
# Presolve removed 1500 rows and 600 columns
# Presolve time: 0.00s
# Presolved: 50 rows, 300 columns, 900 nonzeros
# Found heuristic solution: objective 2064472.0000
# Variable types: 0 continuous, 300 integer (300 binary)
# Found heuristic solution: objective 2071042.0000
#
# Root relaxation: objective 2.071468e+06, 99 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2071468.0000 2071468.00 -0.00%     -    0s
#
# Explored 1 nodes (99 simplex iterations) in 0.01 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 2.07147e+06 2.07104e+06 2.06447e+06 1.4761e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.071468000000e+06, best bound 2.071468000000e+06, gap 0.0000%
# Gurobi status= 2
# Status: Optimal

# %%
# OUTPUT

# OPTIMIZED OBJECTIVE FUNCTION
print("Optimal Total Paid Quantity = ", pulp.value(Promo_Model.objective),"\n")

# PRINTS VARIABLES AND OPTIMAL VALUES
for v in Promo_Model.variables():
    print(v.name, "=", v.varValue)
# Out:
# Optimal Total Paid Quantity =  2071468.0
#
# Free_Quantity_0_0 = 5000.0
# Free_Quantity_0_1 = 5000.0
# Free_Quantity_0_10 = 5000.0
# Free_Quantity_0_11 = 5000.0
# Free_Quantity_0_12 = 5000.0
# Free_Quantity_0_13 = 0.0
# Free_Quantity_0_14 = 5000.0
# Free_Quantity_0_15 = 5000.0
# Free_Quantity_0_16 = 5000.0
# Free_Quantity_0_17 = 5000.0
# Free_Quantity_0_18 = 5000.0
# Free_Quantity_0_19 = 0.0
# Free_Quantity_0_2 = 0.0
# Free_Quantity_0_20 = 0.0
# Free_Quantity_0_21 = 5000.0
# Free_Quantity_0_22 = 5000.0
# Free_Quantity_0_23 = 5000.0
# Free_Quantity_0_24 = 5000.0
# Free_Quantity_0_25 = 5000.0
# Free_Quantity_0_26 = 5000.0
# Free_Quantity_0_27 = 5000.0
# Free_Quantity_0_28 = 5000.0
# Free_Quantity_0_29 = 5000.0
# Free_Quantity_0_3 = 5000.0
# Free_Quantity_0_4 = 5000.0
# Free_Quantity_0_5 = 5000.0
# Free_Quantity_0_6 = 0.0
# Free_Quantity_0_7 = 5000.0
# Free_Quantity_0_8 = 5000.0
# Free_Quantity_0_9 = 5000.0
# Free_Quantity_1_0 = 5000.0
# Free_Quantity_1_1 = 5000.0
# Free_Quantity_1_10 = 5000.0
# Free_Quantity_1_11 = 5000.0
# Free_Quantity_1_12 = 5000.0
# Free_Quantity_1_13 = 5000.0
# Free_Quantity_1_14 = 0.0
# Free_Quantity_1_15 = 5000.0
# Free_Quantity_1_16 = 5000.0
# Free_Quantity_1_17 = 5000.0
# Free_Quantity_1_18 = 5000.0
# Free_Quantity_1_19 = 5000.0
# Free_Quantity_1_2 = 5000.0
# Free_Quantity_1_20 = 5000.0
# Free_Quantity_1_21 = 0.0
# Free_Quantity_1_22 = 0.0
# Free_Quantity_1_23 = 0.0
# Free_Quantity_1_24 = 0.0
# Free_Quantity_1_25 = 0.0
# Free_Quantity_1_26 = 0.0
# Free_Quantity_1_27 = 0.0
# Free_Quantity_1_28 = 0.0
# Free_Quantity_1_29 = 0.0
# Free_Quantity_1_3 = 0.0
# Free_Quantity_1_4 = 0.0
# Free_Quantity_1_5 = 0.0
# Free_Quantity_1_6 = 5000.0
# Free_Quantity_1_7 = 0.0
# Free_Quantity_1_8 = 5000.0
# Free_Quantity_1_9 = 0.0
# Free_Quantity_2_0 = 5000.0
# Free_Quantity_2_1 = 5000.0
# Free_Quantity_2_10 = 5000.0
# Free_Quantity_2_11 = 5000.0
# Free_Quantity_2_12 = 5000.0
# Free_Quantity_2_13 = 5000.0
# Free_Quantity_2_14 = 5000.0
# Free_Quantity_2_15 = 5000.0
# Free_Quantity_2_16 = 0.0
# Free_Quantity_2_17 = 0.0
# Free_Quantity_2_18 = 0.0
# Free_Quantity_2_19 = 5000.0
# Free_Quantity_2_2 = 5000.0
# Free_Quantity_2_20 = 0.0
# Free_Quantity_2_21 = 5000.0
# Free_Quantity_2_22 = 5000.0
# Free_Quantity_2_23 = 5000.0
# Free_Quantity_2_24 = 5000.0
# Free_Quantity_2_25 = 5000.0
# Free_Quantity_2_26 = 5000.0
# Free_Quantity_2_27 = 5000.0
# Free_Quantity_2_28 = 5000.0
# Free_Quantity_2_29 = 5000.0
# Free_Quantity_2_3 = 5000.0
# Free_Quantity_2_4 = 5000.0
# Free_Quantity_2_5 = 5000.0
# Free_Quantity_2_6 = 5000.0
# Free_Quantity_2_7 = 5000.0
# Free_Quantity_2_8 = 5000.0
# Free_Quantity_2_9 = 0.0
# Free_Quantity_3_0 = 5000.0
# Free_Quantity_3_1 = 5000.0
# Free_Quantity_3_10 = 5000.0
# Free_Quantity_3_11 = 5000.0
# Free_Quantity_3_12 = 5000.0
# Free_Quantity_3_13 = 5000.0
# Free_Quantity_3_14 = 5000.0
# Free_Quantity_3_15 = 5000.0
# Free_Quantity_3_16 = 5000.0
# Free_Quantity_3_17 = 0.0
# Free_Quantity_3_18 = 5000.0
# Free_Quantity_3_19 = 5000.0
# Free_Quantity_3_2 = 5000.0
# Free_Quantity_3_20 = 5000.0
# Free_Quantity_3_21 = 5000.0
# Free_Quantity_3_22 = 5000.0
# Free_Quantity_3_23 = 5000.0
# Free_Quantity_3_24 = 5000.0
# Free_Quantity_3_25 = 5000.0
# Free_Quantity_3_26 = 5000.0
# Free_Quantity_3_27 = 0.0
# Free_Quantity_3_28 = 5000.0
# Free_Quantity_3_29 = 0.0
# Free_Quantity_3_3 = 0.0
# Free_Quantity_3_4 = 0.0
# Free_Quantity_3_5 = 5000.0
# Free_Quantity_3_6 = 5000.0
# Free_Quantity_3_7 = 5000.0
# Free_Quantity_3_8 = 5000.0
# Free_Quantity_3_9 = 5000.0
# Free_Quantity_4_0 = 5000.0
# Free_Quantity_4_1 = 5000.0
# Free_Quantity_4_10 = 5000.0
# Free_Quantity_4_11 = 5000.0
# Free_Quantity_4_12 = 5000.0
# Free_Quantity_4_13 = 0.0
# Free_Quantity_4_14 = 0.0
# Free_Quantity_4_15 = 0.0
# Free_Quantity_4_16 = 0.0
# Free_Quantity_4_17 = 5000.0
# Free_Quantity_4_18 = 5000.0
# Free_Quantity_4_19 = 5000.0
# Free_Quantity_4_2 = 5000.0
# Free_Quantity_4_20 = 5000.0
# Free_Quantity_4_21 = 5000.0
# Free_Quantity_4_22 = 5000.0
# Free_Quantity_4_23 = 5000.0
# Free_Quantity_4_24 = 5000.0
# Free_Quantity_4_25 = 5000.0
# Free_Quantity_4_26 = 5000.0
# Free_Quantity_4_27 = 5000.0
# Free_Quantity_4_28 = 5000.0
# Free_Quantity_4_29 = 5000.0
# Free_Quantity_4_3 = 5000.0
# Free_Quantity_4_4 = 5000.0
# Free_Quantity_4_5 = 5000.0
# Free_Quantity_4_6 = 5000.0
# Free_Quantity_4_7 = 5000.0
# Free_Quantity_4_8 = 0.0
# Free_Quantity_4_9 = 5000.0
# Free_Quantity_5_0 = 5000.0
# Free_Quantity_5_1 = 5000.0
# Free_Quantity_5_10 = 5000.0
# Free_Quantity_5_11 = 5000.0
# Free_Quantity_5_12 = 5000.0
# Free_Quantity_5_13 = 5000.0
# Free_Quantity_5_14 = 5000.0
# Free_Quantity_5_15 = 0.0
# Free_Quantity_5_16 = 5000.0
# Free_Quantity_5_17 = 5000.0
# Free_Quantity_5_18 = 5000.0
# Free_Quantity_5_19 = 5000.0
# Free_Quantity_5_2 = 5000.0
# Free_Quantity_5_20 = 5000.0
# Free_Quantity_5_21 = 5000.0
# Free_Quantity_5_22 = 5000.0
# Free_Quantity_5_23 = 0.0
# Free_Quantity_5_24 = 5000.0
# Free_Quantity_5_25 = 5000.0
# Free_Quantity_5_26 = 5000.0
# Free_Quantity_5_27 = 5000.0
# Free_Quantity_5_28 = 5000.0
# Free_Quantity_5_29 = 5000.0
# Free_Quantity_5_3 = 5000.0
# Free_Quantity_5_4 = 5000.0
# Free_Quantity_5_5 = 5000.0
# Free_Quantity_5_6 = 0.0
# Free_Quantity_5_7 = 0.0
# Free_Quantity_5_8 = 0.0
# Free_Quantity_5_9 = 5000.0
# Free_Quantity_6_0 = 0.0
# Free_Quantity_6_1 = 0.0
# Free_Quantity_6_10 = 0.0
# Free_Quantity_6_11 = 5000.0
# Free_Quantity_6_12 = 0.0
# Free_Quantity_6_13 = 5000.0
# Free_Quantity_6_14 = 5000.0
# Free_Quantity_6_15 = 5000.0
# Free_Quantity_6_16 = 5000.0
# Free_Quantity_6_17 = 5000.0
# Free_Quantity_6_18 = 5000.0
# Free_Quantity_6_19 = 5000.0
# Free_Quantity_6_2 = 5000.0
# Free_Quantity_6_20 = 5000.0
# Free_Quantity_6_21 = 5000.0
# Free_Quantity_6_22 = 0.0
# Free_Quantity_6_23 = 5000.0
# Free_Quantity_6_24 = 5000.0
# Free_Quantity_6_25 = 5000.0
# Free_Quantity_6_26 = 5000.0
# Free_Quantity_6_27 = 5000.0
# Free_Quantity_6_28 = 5000.0
# Free_Quantity_6_29 = 5000.0
# Free_Quantity_6_3 = 5000.0
# Free_Quantity_6_4 = 5000.0
# Free_Quantity_6_5 = 5000.0
# Free_Quantity_6_6 = 5000.0
# Free_Quantity_6_7 = 5000.0
# Free_Quantity_6_8 = 5000.0
# Free_Quantity_6_9 = 5000.0
# Free_Quantity_7_0 = 5000.0
# Free_Quantity_7_1 = 5000.0
# Free_Quantity_7_10 = 5000.0
# Free_Quantity_7_11 = 5000.0
# Free_Quantity_7_12 = 5000.0
# Free_Quantity_7_13 = 5000.0
# Free_Quantity_7_14 = 5000.0
# Free_Quantity_7_15 = 5000.0
# Free_Quantity_7_16 = 5000.0
# Free_Quantity_7_17 = 5000.0
# Free_Quantity_7_18 = 5000.0
# Free_Quantity_7_19 = 0.0
# Free_Quantity_7_2 = 0.0
# Free_Quantity_7_20 = 5000.0
# Free_Quantity_7_21 = 5000.0
# Free_Quantity_7_22 = 5000.0
# Free_Quantity_7_23 = 5000.0
# Free_Quantity_7_24 = 5000.0
# Free_Quantity_7_25 = 0.0
# Free_Quantity_7_26 = 5000.0
# Free_Quantity_7_27 = 5000.0
# Free_Quantity_7_28 = 0.0
# Free_Quantity_7_29 = 5000.0
# Free_Quantity_7_3 = 5000.0
# Free_Quantity_7_4 = 5000.0
# Free_Quantity_7_5 = 0.0
# Free_Quantity_7_6 = 5000.0
# Free_Quantity_7_7 = 5000.0
# Free_Quantity_7_8 = 5000.0
# Free_Quantity_7_9 = 5000.0
# Free_Quantity_8_0 = 0.0
# Free_Quantity_8_1 = 0.0
# Free_Quantity_8_10 = 5000.0
# Free_Quantity_8_11 = 0.0
# Free_Quantity_8_12 = 0.0
# Free_Quantity_8_13 = 5000.0
# Free_Quantity_8_14 = 5000.0
# Free_Quantity_8_15 = 5000.0
# Free_Quantity_8_16 = 5000.0
# Free_Quantity_8_17 = 5000.0
# Free_Quantity_8_18 = 5000.0
# Free_Quantity_8_19 = 5000.0
# Free_Quantity_8_2 = 5000.0
# Free_Quantity_8_20 = 5000.0
# Free_Quantity_8_21 = 5000.0
# Free_Quantity_8_22 = 5000.0
# Free_Quantity_8_23 = 5000.0
# Free_Quantity_8_24 = 5000.0
# Free_Quantity_8_25 = 5000.0
# Free_Quantity_8_26 = 0.0
# Free_Quantity_8_27 = 5000.0
# Free_Quantity_8_28 = 5000.0
# Free_Quantity_8_29 = 5000.0
# Free_Quantity_8_3 = 5000.0
# Free_Quantity_8_4 = 5000.0
# Free_Quantity_8_5 = 5000.0
# Free_Quantity_8_6 = 5000.0
# Free_Quantity_8_7 = 5000.0
# Free_Quantity_8_8 = 5000.0
# Free_Quantity_8_9 = 5000.0
# Free_Quantity_9_0 = 5000.0
# Free_Quantity_9_1 = 5000.0
# Free_Quantity_9_10 = 0.0
# Free_Quantity_9_11 = 0.0
# Free_Quantity_9_12 = 5000.0
# Free_Quantity_9_13 = 5000.0
# Free_Quantity_9_14 = 5000.0
# Free_Quantity_9_15 = 5000.0
# Free_Quantity_9_16 = 5000.0
# Free_Quantity_9_17 = 5000.0
# Free_Quantity_9_18 = 0.0
# Free_Quantity_9_19 = 5000.0
# Free_Quantity_9_2 = 5000.0
# Free_Quantity_9_20 = 5000.0
# Free_Quantity_9_21 = 0.0
# Free_Quantity_9_22 = 5000.0
# Free_Quantity_9_23 = 5000.0
# Free_Quantity_9_24 = 0.0
# Free_Quantity_9_25 = 5000.0
# Free_Quantity_9_26 = 5000.0
# Free_Quantity_9_27 = 5000.0
# Free_Quantity_9_28 = 5000.0
# Free_Quantity_9_29 = 5000.0
# Free_Quantity_9_3 = 5000.0
# Free_Quantity_9_4 = 5000.0
# Free_Quantity_9_5 = 5000.0
# Free_Quantity_9_6 = 5000.0
# Free_Quantity_9_7 = 5000.0
# Free_Quantity_9_8 = 5000.0
# Free_Quantity_9_9 = 5000.0
# IsPromoted_0_0 = 1.0
# IsPromoted_0_1 = 1.0
# IsPromoted_0_10 = 1.0
# IsPromoted_0_11 = 1.0
# IsPromoted_0_12 = 1.0
# IsPromoted_0_13 = -0.0
# IsPromoted_0_14 = 1.0
# IsPromoted_0_15 = 1.0
# IsPromoted_0_16 = 1.0
# IsPromoted_0_17 = 1.0
# IsPromoted_0_18 = 1.0
# IsPromoted_0_19 = -0.0
# IsPromoted_0_2 = 0.0
# IsPromoted_0_20 = 0.0
# IsPromoted_0_21 = 1.0
# IsPromoted_0_22 = 1.0
# IsPromoted_0_23 = 1.0
# IsPromoted_0_24 = 1.0
# IsPromoted_0_25 = 1.0
# IsPromoted_0_26 = 1.0
# IsPromoted_0_27 = 1.0
# IsPromoted_0_28 = 1.0
# IsPromoted_0_29 = 1.0
# IsPromoted_0_3 = 1.0
# IsPromoted_0_4 = 1.0
# IsPromoted_0_5 = 1.0
# IsPromoted_0_6 = -0.0
# IsPromoted_0_7 = 1.0
# IsPromoted_0_8 = 1.0
# IsPromoted_0_9 = 1.0
# IsPromoted_1_0 = 1.0
# IsPromoted_1_1 = 1.0
# IsPromoted_1_10 = 1.0
# IsPromoted_1_11 = 1.0
# IsPromoted_1_12 = 1.0
# IsPromoted_1_13 = 1.0
# IsPromoted_1_14 = -0.0
# IsPromoted_1_15 = 1.0
# IsPromoted_1_16 = 1.0
# IsPromoted_1_17 = 1.0
# IsPromoted_1_18 = 1.0
# IsPromoted_1_19 = 1.0
# IsPromoted_1_2 = 1.0
# IsPromoted_1_20 = 1.0
# IsPromoted_1_21 = -0.0
# IsPromoted_1_22 = -0.0
# IsPromoted_1_23 = -0.0
# IsPromoted_1_24 = -0.0
# IsPromoted_1_25 = -0.0
# IsPromoted_1_26 = -0.0
# IsPromoted_1_27 = -0.0
# IsPromoted_1_28 = -0.0
# IsPromoted_1_29 = -0.0
# IsPromoted_1_3 = -0.0
# IsPromoted_1_4 = 0.0
# IsPromoted_1_5 = -0.0
# IsPromoted_1_6 = 1.0
# IsPromoted_1_7 = -0.0
# IsPromoted_1_8 = 1.0
# IsPromoted_1_9 = -0.0
# IsPromoted_2_0 = 1.0
# IsPromoted_2_1 = 1.0
# IsPromoted_2_10 = 1.0
# IsPromoted_2_11 = 1.0
# IsPromoted_2_12 = 1.0
# IsPromoted_2_13 = 1.0
# IsPromoted_2_14 = 1.0
# IsPromoted_2_15 = 1.0
# IsPromoted_2_16 = 0.0
# IsPromoted_2_17 = -0.0
# IsPromoted_2_18 = -0.0
# IsPromoted_2_19 = 1.0
# IsPromoted_2_2 = 1.0
# IsPromoted_2_20 = -0.0
# IsPromoted_2_21 = 1.0
# IsPromoted_2_22 = 1.0
# IsPromoted_2_23 = 1.0
# IsPromoted_2_24 = 1.0
# IsPromoted_2_25 = 1.0
# IsPromoted_2_26 = 1.0
# IsPromoted_2_27 = 1.0
# IsPromoted_2_28 = 1.0
# IsPromoted_2_29 = 1.0
# IsPromoted_2_3 = 1.0
# IsPromoted_2_4 = 1.0
# IsPromoted_2_5 = 1.0
# IsPromoted_2_6 = 1.0
# IsPromoted_2_7 = 1.0
# IsPromoted_2_8 = 1.0
# IsPromoted_2_9 = -0.0
# IsPromoted_3_0 = 1.0
# IsPromoted_3_1 = 1.0
# IsPromoted_3_10 = 1.0
# IsPromoted_3_11 = 1.0
# IsPromoted_3_12 = 1.0
# IsPromoted_3_13 = 1.0
# IsPromoted_3_14 = 1.0
# IsPromoted_3_15 = 1.0
# IsPromoted_3_16 = 1.0
# IsPromoted_3_17 = -0.0
# IsPromoted_3_18 = 1.0
# IsPromoted_3_19 = 1.0
# IsPromoted_3_2 = 1.0
# IsPromoted_3_20 = 1.0
# IsPromoted_3_21 = 1.0
# IsPromoted_3_22 = 1.0
# IsPromoted_3_23 = 1.0
# IsPromoted_3_24 = 1.0
# IsPromoted_3_25 = 1.0
# IsPromoted_3_26 = 1.0
# IsPromoted_3_27 = -0.0
# IsPromoted_3_28 = 1.0
# IsPromoted_3_29 = -0.0
# IsPromoted_3_3 = -0.0
# IsPromoted_3_4 = -0.0
# IsPromoted_3_5 = 1.0
# IsPromoted_3_6 = 1.0
# IsPromoted_3_7 = 1.0
# IsPromoted_3_8 = 1.0
# IsPromoted_3_9 = 1.0
# IsPromoted_4_0 = 1.0
# IsPromoted_4_1 = 1.0
# IsPromoted_4_10 = 1.0
# IsPromoted_4_11 = 1.0
# IsPromoted_4_12 = 1.0
# IsPromoted_4_13 = -0.0
# IsPromoted_4_14 = -0.0
# IsPromoted_4_15 = -0.0
# IsPromoted_4_16 = -0.0
# IsPromoted_4_17 = 1.0
# IsPromoted_4_18 = 1.0
# IsPromoted_4_19 = 1.0
# IsPromoted_4_2 = 1.0
# IsPromoted_4_20 = 1.0
# IsPromoted_4_21 = 1.0
# IsPromoted_4_22 = 1.0
# IsPromoted_4_23 = 1.0
# IsPromoted_4_24 = 1.0
# IsPromoted_4_25 = 1.0
# IsPromoted_4_26 = 1.0
# IsPromoted_4_27 = 1.0
# IsPromoted_4_28 = 1.0
# IsPromoted_4_29 = 1.0
# IsPromoted_4_3 = 1.0
# IsPromoted_4_4 = 1.0
# IsPromoted_4_5 = 1.0
# IsPromoted_4_6 = 1.0
# IsPromoted_4_7 = 1.0
# IsPromoted_4_8 = -0.0
# IsPromoted_4_9 = 1.0
# IsPromoted_5_0 = 1.0
# IsPromoted_5_1 = 1.0
# IsPromoted_5_10 = 1.0
# IsPromoted_5_11 = 1.0
# IsPromoted_5_12 = 1.0
# IsPromoted_5_13 = 1.0
# IsPromoted_5_14 = 1.0
# IsPromoted_5_15 = 0.0
# IsPromoted_5_16 = 1.0
# IsPromoted_5_17 = 1.0
# IsPromoted_5_18 = 1.0
# IsPromoted_5_19 = 1.0
# IsPromoted_5_2 = 1.0
# IsPromoted_5_20 = 1.0
# IsPromoted_5_21 = 1.0
# IsPromoted_5_22 = 1.0
# IsPromoted_5_23 = -0.0
# IsPromoted_5_24 = 1.0
# IsPromoted_5_25 = 1.0
# IsPromoted_5_26 = 1.0
# IsPromoted_5_27 = 1.0
# IsPromoted_5_28 = 1.0
# IsPromoted_5_29 = 1.0
# IsPromoted_5_3 = 1.0
# IsPromoted_5_4 = 1.0
# IsPromoted_5_5 = 1.0
# IsPromoted_5_6 = -0.0
# IsPromoted_5_7 = -0.0
# IsPromoted_5_8 = -0.0
# IsPromoted_5_9 = 1.0
# IsPromoted_6_0 = -0.0
# IsPromoted_6_1 = -0.0
# IsPromoted_6_10 = 0.0
# IsPromoted_6_11 = 1.0
# IsPromoted_6_12 = -0.0
# IsPromoted_6_13 = 1.0
# IsPromoted_6_14 = 1.0
# IsPromoted_6_15 = 1.0
# IsPromoted_6_16 = 1.0
# IsPromoted_6_17 = 1.0
# IsPromoted_6_18 = 1.0
# IsPromoted_6_19 = 1.0
# IsPromoted_6_2 = 1.0
# IsPromoted_6_20 = 1.0
# IsPromoted_6_21 = 1.0
# IsPromoted_6_22 = -0.0
# IsPromoted_6_23 = 1.0
# IsPromoted_6_24 = 1.0
# IsPromoted_6_25 = 1.0
# IsPromoted_6_26 = 1.0
# IsPromoted_6_27 = 1.0
# IsPromoted_6_28 = 1.0
# IsPromoted_6_29 = 1.0
# IsPromoted_6_3 = 1.0
# IsPromoted_6_4 = 1.0
# IsPromoted_6_5 = 1.0
# IsPromoted_6_6 = 1.0
# IsPromoted_6_7 = 1.0
# IsPromoted_6_8 = 1.0
# IsPromoted_6_9 = 1.0
# IsPromoted_7_0 = 1.0
# IsPromoted_7_1 = 1.0
# IsPromoted_7_10 = 1.0
# IsPromoted_7_11 = 1.0
# IsPromoted_7_12 = 1.0
# IsPromoted_7_13 = 1.0
# IsPromoted_7_14 = 1.0
# IsPromoted_7_15 = 1.0
# IsPromoted_7_16 = 1.0
# IsPromoted_7_17 = 1.0
# IsPromoted_7_18 = 1.0
# IsPromoted_7_19 = 0.0
# IsPromoted_7_2 = -0.0
# IsPromoted_7_20 = 1.0
# IsPromoted_7_21 = 1.0
# IsPromoted_7_22 = 1.0
# IsPromoted_7_23 = 1.0
# IsPromoted_7_24 = 1.0
# IsPromoted_7_25 = 0.0
# IsPromoted_7_26 = 1.0
# IsPromoted_7_27 = 1.0
# IsPromoted_7_28 = 0.0
# IsPromoted_7_29 = 1.0
# IsPromoted_7_3 = 1.0
# IsPromoted_7_4 = 1.0
# IsPromoted_7_5 = -0.0
# IsPromoted_7_6 = 1.0
# IsPromoted_7_7 = 1.0
# IsPromoted_7_8 = 1.0
# IsPromoted_7_9 = 1.0
# IsPromoted_8_0 = -0.0
# IsPromoted_8_1 = -0.0
# IsPromoted_8_10 = 1.0
# IsPromoted_8_11 = -0.0
# IsPromoted_8_12 = -0.0
# IsPromoted_8_13 = 1.0
# IsPromoted_8_14 = 1.0
# IsPromoted_8_15 = 1.0
# IsPromoted_8_16 = 1.0
# IsPromoted_8_17 = 1.0
# IsPromoted_8_18 = 1.0
# IsPromoted_8_19 = 1.0
# IsPromoted_8_2 = 1.0
# IsPromoted_8_20 = 1.0
# IsPromoted_8_21 = 1.0
# IsPromoted_8_22 = 1.0
# IsPromoted_8_23 = 1.0
# IsPromoted_8_24 = 1.0
# IsPromoted_8_25 = 1.0
# IsPromoted_8_26 = 0.0
# IsPromoted_8_27 = 1.0
# IsPromoted_8_28 = 1.0
# IsPromoted_8_29 = 1.0
# IsPromoted_8_3 = 1.0
# IsPromoted_8_4 = 1.0
# IsPromoted_8_5 = 1.0
# IsPromoted_8_6 = 1.0
# IsPromoted_8_7 = 1.0
# IsPromoted_8_8 = 1.0
# IsPromoted_8_9 = 1.0
# IsPromoted_9_0 = 1.0
# IsPromoted_9_1 = 1.0
# IsPromoted_9_10 = -0.0
# IsPromoted_9_11 = -0.0
# IsPromoted_9_12 = 1.0
# IsPromoted_9_13 = 1.0
# IsPromoted_9_14 = 1.0
# IsPromoted_9_15 = 1.0
# IsPromoted_9_16 = 1.0
# IsPromoted_9_17 = 1.0
# IsPromoted_9_18 = 0.0
# IsPromoted_9_19 = 1.0
# IsPromoted_9_2 = 1.0
# IsPromoted_9_20 = 1.0
# IsPromoted_9_21 = -0.0
# IsPromoted_9_22 = 1.0
# IsPromoted_9_23 = 1.0
# IsPromoted_9_24 = 0.0
# IsPromoted_9_25 = 1.0
# IsPromoted_9_26 = 1.0
# IsPromoted_9_27 = 1.0
# IsPromoted_9_28 = 1.0
# IsPromoted_9_29 = 1.0
# IsPromoted_9_3 = 1.0
# IsPromoted_9_4 = 1.0
# IsPromoted_9_5 = 1.0
# IsPromoted_9_6 = 1.0
# IsPromoted_9_7 = 1.0
# IsPromoted_9_8 = 1.0
# IsPromoted_9_9 = 1.0
# Paid_Quantity_0_0 = 10921.0
# Paid_Quantity_0_1 = 7743.0
# Paid_Quantity_0_10 = 9698.0
# Paid_Quantity_0_11 = 2348.0
# Paid_Quantity_0_12 = 8068.0
# Paid_Quantity_0_13 = 4828.0
# Paid_Quantity_0_14 = 4050.0
# Paid_Quantity_0_15 = 4247.0
# Paid_Quantity_0_16 = 9041.0
# Paid_Quantity_0_17 = 7206.0
# Paid_Quantity_0_18 = 5774.0
# Paid_Quantity_0_19 = 4471.0
# Paid_Quantity_0_2 = 8636.0
# Paid_Quantity_0_20 = 8809.0
# Paid_Quantity_0_21 = 10002.0
# Paid_Quantity_0_22 = 10511.0
# Paid_Quantity_0_23 = 3974.0
# Paid_Quantity_0_24 = 8462.0
# Paid_Quantity_0_25 = 9445.0
# Paid_Quantity_0_26 = 7103.0
# Paid_Quantity_0_27 = 9787.0
# Paid_Quantity_0_28 = 7408.0
# Paid_Quantity_0_29 = 5630.0
# Paid_Quantity_0_3 = 7609.0
# Paid_Quantity_0_4 = 6828.0
# Paid_Quantity_0_5 = 5318.0
# Paid_Quantity_0_6 = 5271.0
# Paid_Quantity_0_7 = 4205.0
# Paid_Quantity_0_8 = 5923.0
# Paid_Quantity_0_9 = 5830.0
# Paid_Quantity_1_0 = 7455.0
# Paid_Quantity_1_1 = 2504.0
# Paid_Quantity_1_10 = 8542.0
# Paid_Quantity_1_11 = 10580.0
# Paid_Quantity_1_12 = 5929.0
# Paid_Quantity_1_13 = 5207.0
# Paid_Quantity_1_14 = 1805.0
# Paid_Quantity_1_15 = 7203.0
# Paid_Quantity_1_16 = 5821.0
# Paid_Quantity_1_17 = 7517.0
# Paid_Quantity_1_18 = 4348.0
# Paid_Quantity_1_19 = 4171.0
# Paid_Quantity_1_2 = 8346.0
# Paid_Quantity_1_20 = 9523.0
# Paid_Quantity_1_21 = 1687.0
# Paid_Quantity_1_22 = 8392.0
# Paid_Quantity_1_23 = 4171.0
# Paid_Quantity_1_24 = 4155.0
# Paid_Quantity_1_25 = 5440.0
# Paid_Quantity_1_26 = 6888.0
# Paid_Quantity_1_27 = 5697.0
# Paid_Quantity_1_28 = 2297.0
# Paid_Quantity_1_29 = 1017.0
# Paid_Quantity_1_3 = 8857.0
# Paid_Quantity_1_4 = 5666.0
# Paid_Quantity_1_5 = 2480.0
# Paid_Quantity_1_6 = 10651.0
# Paid_Quantity_1_7 = 1138.0
# Paid_Quantity_1_8 = 2861.0
# Paid_Quantity_1_9 = 1017.0
# Paid_Quantity_2_0 = 4210.0
# Paid_Quantity_2_1 = 4872.0
# Paid_Quantity_2_10 = 4754.0
# Paid_Quantity_2_11 = 5771.0
# Paid_Quantity_2_12 = 5716.0
# Paid_Quantity_2_13 = 6408.0
# Paid_Quantity_2_14 = 3960.0
# Paid_Quantity_2_15 = 9232.0
# Paid_Quantity_2_16 = 2878.0
# Paid_Quantity_2_17 = 5245.0
# Paid_Quantity_2_18 = 3451.0
# Paid_Quantity_2_19 = 9040.0
# Paid_Quantity_2_2 = 5830.0
# Paid_Quantity_2_20 = 8056.0
# Paid_Quantity_2_21 = 10566.0
# Paid_Quantity_2_22 = 3890.0
# Paid_Quantity_2_23 = 12014.0
# Paid_Quantity_2_24 = 11630.0
# Paid_Quantity_2_25 = 6205.0
# Paid_Quantity_2_26 = 6413.0
# Paid_Quantity_2_27 = 8473.0
# Paid_Quantity_2_28 = 13204.0
# Paid_Quantity_2_29 = 7777.0
# Paid_Quantity_2_3 = 10932.0
# Paid_Quantity_2_4 = 9474.0
# Paid_Quantity_2_5 = 8928.0
# Paid_Quantity_2_6 = 6987.0
# Paid_Quantity_2_7 = 8116.0
# Paid_Quantity_2_8 = 8983.0
# Paid_Quantity_2_9 = 1880.0
# Paid_Quantity_3_0 = 6089.0
# Paid_Quantity_3_1 = 9558.0
# Paid_Quantity_3_10 = 2554.0
# Paid_Quantity_3_11 = 8241.0
# Paid_Quantity_3_12 = 4495.0
# Paid_Quantity_3_13 = 1909.0
# Paid_Quantity_3_14 = 1248.0
# Paid_Quantity_3_15 = 2724.0
# Paid_Quantity_3_16 = 10798.0
# Paid_Quantity_3_17 = 9837.0
# Paid_Quantity_3_18 = 4594.0
# Paid_Quantity_3_19 = 3381.0
# Paid_Quantity_3_2 = 3777.0
# Paid_Quantity_3_20 = 3845.0
# Paid_Quantity_3_21 = 8664.0
# Paid_Quantity_3_22 = 3015.0
# Paid_Quantity_3_23 = 5179.0
# Paid_Quantity_3_24 = 1859.0
# Paid_Quantity_3_25 = 4090.0
# Paid_Quantity_3_26 = 3937.0
# Paid_Quantity_3_27 = 3248.0
# Paid_Quantity_3_28 = 2988.0
# Paid_Quantity_3_29 = 7790.0
# Paid_Quantity_3_3 = 7966.0
# Paid_Quantity_3_4 = 9902.0
# Paid_Quantity_3_5 = 9251.0
# Paid_Quantity_3_6 = 5379.0
# Paid_Quantity_3_7 = 9042.0
# Paid_Quantity_3_8 = 8788.0
# Paid_Quantity_3_9 = 2557.0
# Paid_Quantity_4_0 = 10763.0
# Paid_Quantity_4_1 = 3861.0
# Paid_Quantity_4_10 = 3622.0
# Paid_Quantity_4_11 = 4943.0
# Paid_Quantity_4_12 = 5411.0
# Paid_Quantity_4_13 = 4680.0
# Paid_Quantity_4_14 = 4355.0
# Paid_Quantity_4_15 = 669.0
# Paid_Quantity_4_16 = 3599.0
# Paid_Quantity_4_17 = 5100.0
# Paid_Quantity_4_18 = 8437.0
# Paid_Quantity_4_19 = 7227.0
# Paid_Quantity_4_2 = 8654.0
# Paid_Quantity_4_20 = 7254.0
# Paid_Quantity_4_21 = 4007.0
# Paid_Quantity_4_22 = 11731.0
# Paid_Quantity_4_23 = 8890.0
# Paid_Quantity_4_24 = 12231.0
# Paid_Quantity_4_25 = 12925.0
# Paid_Quantity_4_26 = 12315.0
# Paid_Quantity_4_27 = 8015.0
# Paid_Quantity_4_28 = 5733.0
# Paid_Quantity_4_29 = 4573.0
# Paid_Quantity_4_3 = 4753.0
# Paid_Quantity_4_4 = 6998.0
# Paid_Quantity_4_5 = 4826.0
# Paid_Quantity_4_6 = 13110.0
# Paid_Quantity_4_7 = 4106.0
# Paid_Quantity_4_8 = 5860.0
# Paid_Quantity_4_9 = 12191.0
# Paid_Quantity_5_0 = 5645.0
# Paid_Quantity_5_1 = 12979.0
# Paid_Quantity_5_10 = 12684.0
# Paid_Quantity_5_11 = 9628.0
# Paid_Quantity_5_12 = 4504.0
# Paid_Quantity_5_13 = 9251.0
# Paid_Quantity_5_14 = 8901.0
# Paid_Quantity_5_15 = 3526.0
# Paid_Quantity_5_16 = 4943.0
# Paid_Quantity_5_17 = 4154.0
# Paid_Quantity_5_18 = 12924.0
# Paid_Quantity_5_19 = 11140.0
# Paid_Quantity_5_2 = 7081.0
# Paid_Quantity_5_20 = 3899.0
# Paid_Quantity_5_21 = 6796.0
# Paid_Quantity_5_22 = 6788.0
# Paid_Quantity_5_23 = 6831.0
# Paid_Quantity_5_24 = 6871.0
# Paid_Quantity_5_25 = 8660.0
# Paid_Quantity_5_26 = 4791.0
# Paid_Quantity_5_27 = 5803.0
# Paid_Quantity_5_28 = 5887.0
# Paid_Quantity_5_29 = 11290.0
# Paid_Quantity_5_3 = 11271.0
# Paid_Quantity_5_4 = 4257.0
# Paid_Quantity_5_5 = 5118.0
# Paid_Quantity_5_6 = 1280.0
# Paid_Quantity_5_7 = 4987.0
# Paid_Quantity_5_8 = 5841.0
# Paid_Quantity_5_9 = 10846.0
# Paid_Quantity_6_0 = 1717.0
# Paid_Quantity_6_1 = 2895.0
# Paid_Quantity_6_10 = 8471.0
# Paid_Quantity_6_11 = 9865.0
# Paid_Quantity_6_12 = 4980.0
# Paid_Quantity_6_13 = 7562.0
# Paid_Quantity_6_14 = 8678.0
# Paid_Quantity_6_15 = 10397.0
# Paid_Quantity_6_16 = 11565.0
# Paid_Quantity_6_17 = 4932.0
# Paid_Quantity_6_18 = 3910.0
# Paid_Quantity_6_19 = 3984.0
# Paid_Quantity_6_2 = 9093.0
# Paid_Quantity_6_20 = 4399.0
# Paid_Quantity_6_21 = 8068.0
# Paid_Quantity_6_22 = 4991.0
# Paid_Quantity_6_23 = 11145.0
# Paid_Quantity_6_24 = 12195.0
# Paid_Quantity_6_25 = 4372.0
# Paid_Quantity_6_26 = 8507.0
# Paid_Quantity_6_27 = 8184.0
# Paid_Quantity_6_28 = 10496.0
# Paid_Quantity_6_29 = 9179.0
# Paid_Quantity_6_3 = 8914.0
# Paid_Quantity_6_4 = 6177.0
# Paid_Quantity_6_5 = 12258.0
# Paid_Quantity_6_6 = 6995.0
# Paid_Quantity_6_7 = 11332.0
# Paid_Quantity_6_8 = 9158.0
# Paid_Quantity_6_9 = 7034.0
# Paid_Quantity_7_0 = 8862.0
# Paid_Quantity_7_1 = 5184.0
# Paid_Quantity_7_10 = 12820.0
# Paid_Quantity_7_11 = 7365.0
# Paid_Quantity_7_12 = 13480.0
# Paid_Quantity_7_13 = 12146.0
# Paid_Quantity_7_14 = 10826.0
# Paid_Quantity_7_15 = 11348.0
# Paid_Quantity_7_16 = 6695.0
# Paid_Quantity_7_17 = 10673.0
# Paid_Quantity_7_18 = 5590.0
# Paid_Quantity_7_19 = 7569.0
# Paid_Quantity_7_2 = 8815.0
# Paid_Quantity_7_20 = 11054.0
# Paid_Quantity_7_21 = 8335.0
# Paid_Quantity_7_22 = 13366.0
# Paid_Quantity_7_23 = 11763.0
# Paid_Quantity_7_24 = 4458.0
# Paid_Quantity_7_25 = 6043.0
# Paid_Quantity_7_26 = 12178.0
# Paid_Quantity_7_27 = 12402.0
# Paid_Quantity_7_28 = 9844.0
# Paid_Quantity_7_29 = 14391.0
# Paid_Quantity_7_3 = 13689.0
# Paid_Quantity_7_4 = 6033.0
# Paid_Quantity_7_5 = 7367.0
# Paid_Quantity_7_6 = 7814.0
# Paid_Quantity_7_7 = 13688.0
# Paid_Quantity_7_8 = 13668.0
# Paid_Quantity_7_9 = 5404.0
# Paid_Quantity_8_0 = 2013.0
# Paid_Quantity_8_1 = 6108.0
# Paid_Quantity_8_10 = 5896.0
# Paid_Quantity_8_11 = 4815.0
# Paid_Quantity_8_12 = 4435.0
# Paid_Quantity_8_13 = 3956.0
# Paid_Quantity_8_14 = 3821.0
# Paid_Quantity_8_15 = 2180.0
# Paid_Quantity_8_16 = 9877.0
# Paid_Quantity_8_17 = 5976.0
# Paid_Quantity_8_18 = 6154.0
# Paid_Quantity_8_19 = 10085.0
# Paid_Quantity_8_2 = 3864.0
# Paid_Quantity_8_20 = 2805.0
# Paid_Quantity_8_21 = 10924.0
# Paid_Quantity_8_22 = 5706.0
# Paid_Quantity_8_23 = 6602.0
# Paid_Quantity_8_24 = 2709.0
# Paid_Quantity_8_25 = 1945.0
# Paid_Quantity_8_26 = 6183.0
# Paid_Quantity_8_27 = 10809.0
# Paid_Quantity_8_28 = 6050.0
# Paid_Quantity_8_29 = 6791.0
# Paid_Quantity_8_3 = 8422.0
# Paid_Quantity_8_4 = 5446.0
# Paid_Quantity_8_5 = 2017.0
# Paid_Quantity_8_6 = 2200.0
# Paid_Quantity_8_7 = 9294.0
# Paid_Quantity_8_8 = 9571.0
# Paid_Quantity_8_9 = 3929.0
# Paid_Quantity_9_0 = 11167.0
# Paid_Quantity_9_1 = 9286.0
# Paid_Quantity_9_10 = 9977.0
# Paid_Quantity_9_11 = 2880.0
# Paid_Quantity_9_12 = 11483.0
# Paid_Quantity_9_13 = 11235.0
# Paid_Quantity_9_14 = 4095.0
# Paid_Quantity_9_15 = 7229.0
# Paid_Quantity_9_16 = 5785.0
# Paid_Quantity_9_17 = 7259.0
# Paid_Quantity_9_18 = 4680.0
# Paid_Quantity_9_19 = 7707.0
# Paid_Quantity_9_2 = 11605.0
# Paid_Quantity_9_20 = 11207.0
# Paid_Quantity_9_21 = 955.0
# Paid_Quantity_9_22 = 5814.0
# Paid_Quantity_9_23 = 9709.0
# Paid_Quantity_9_24 = 520.0
# Paid_Quantity_9_25 = 2731.0
# Paid_Quantity_9_26 = 3406.0
# Paid_Quantity_9_27 = 8921.0
# Paid_Quantity_9_28 = 2776.0
# Paid_Quantity_9_29 = 2667.0
# Paid_Quantity_9_3 = 11652.0
# Paid_Quantity_9_4 = 10990.0
# Paid_Quantity_9_5 = 5100.0
# Paid_Quantity_9_6 = 3494.0
# Paid_Quantity_9_7 = 3817.0
# Paid_Quantity_9_8 = 2468.0
# Paid_Quantity_9_9 = 4421.0

# %%
#PROMO RATIO IS CALCULATED BASED ON THE OPTIMUM P[i][t] AND F[i][t] VALUES
Promo_Ratio = np.zeros((I, T), dtype = float)

for i in Products:
    for t in PHorizon:
        Promo_Ratio[i][t] = (F[i][t].varValue)/(P[i][t].varValue + F[i][t].varValue)

df_Promo_Ratio = pd.DataFrame(Promo_Ratio,
                 index=range(1,I+1),
                 columns=range(1,T+1))
df_Promo_Ratio
# Out:
#           1         2         3         4         5         6         7   \
# 1   0.314051  0.392372  0.000000  0.396542  0.422726  0.484590  0.000000
# 2   0.401445  0.666311  0.374644  0.000000  0.000000  0.000000  0.319468
# 3   0.542888  0.506483  0.461681  0.313834  0.345447  0.358989  0.417119
# 4   0.450897  0.343454  0.569671  0.000000  0.000000  0.350853  0.481742
# 5   0.317199  0.564270  0.366193  0.512663  0.416736  0.508854  0.276091
# 6   0.469704  0.278102  0.413873  0.307295  0.540132  0.494169  0.000000
# 7   0.000000  0.000000  0.354786  0.359350  0.447347  0.289721  0.416840
# 8   0.360698  0.490966  0.000000  0.267537  0.453186  0.000000  0.390198
# 9   0.000000  0.000000  0.564079  0.372523  0.478652  0.712555  0.694444
# 10  0.309272  0.349993  0.301114  0.300264  0.312695  0.495050  0.588651
#
#           8         9         10  ...        21        22        23        24  \
# 1   0.543183  0.457750  0.461681  ...  0.000000  0.333289  0.322352  0.557165
# 2   0.000000  0.636051  0.000000  ...  0.344281  0.000000  0.000000  0.000000
# 3   0.381214  0.357577  0.000000  ...  0.000000  0.321213  0.562430  0.293876
# 4   0.356075  0.362634  0.661638  ...  0.565291  0.365925  0.623830  0.491207
# 5   0.549089  0.000000  0.290850  ...  0.408030  0.555124  0.298846  0.359971
# 6   0.000000  0.000000  0.315537  ...  0.561861  0.423872  0.424160  0.000000
# 7   0.306147  0.353157  0.415489  ...  0.531971  0.382614  0.000000  0.309693
# 8   0.267551  0.267838  0.480584  ...  0.311449  0.374953  0.272242  0.298276
# 9   0.349797  0.343147  0.559973  ...  0.640615  0.313991  0.467028  0.430960
# 10  0.567086  0.669523  0.530729  ...  0.308509  0.000000  0.462364  0.339928
#
#           25        26        27        28        29        30
# 1   0.371416  0.346141  0.413121  0.338135  0.402966  0.470367
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.300661  0.446229  0.438097  0.371113  0.274665  0.391328
# 4   0.728969  0.550055  0.559472  0.000000  0.625939  0.000000
# 5   0.290175  0.278940  0.288767  0.384172  0.465853  0.522302
# 6   0.421195  0.366032  0.510673  0.462834  0.459263  0.306937
# 7   0.290782  0.533504  0.370178  0.379248  0.322664  0.352634
# 8   0.528653  0.000000  0.291070  0.287323  0.000000  0.257852
# 9   0.648593  0.719942  0.000000  0.316276  0.452489  0.424052
# 10  0.000000  0.646747  0.594813  0.359170  0.643004  0.652146
#
# [10 rows x 30 columns]

# %%
Promo_Sensitivity
# Out:
# array([1.19488356, 1.13720047, 1.65060048, 1.17997442, 1.65451094,
#        1.76058517, 1.73279655, 1.88830118, 1.25199053, 1.36807305])
