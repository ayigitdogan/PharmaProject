# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt
import seaborn as sns
from matplotlib import style
import math
import random

# %%
#LP MAXIMIZATION MODEL

from pulp import *
Promo_Model = LpProblem("Pharma_Promotion_Model", LpMaximize)

# %%
#PARAMETERS

T=12 # end of promotion horizon
PHorizon = list(range(0, T))

I=10 # product count 
Products = list(range(0, I))

#NOT USED RIGHT NOW
Promo_Levels = [0,1,2]

Demand = np.zeros((I, T), dtype = int)

for i in Products:
    for t in PHorizon:
       Demand[i][t] = random.randint(0, 10000)
    
Total_PaidQty_Limit = 1000000
Total_FreeQty_Limit = 250000

Demand
# Out:
# array([[4837, 4626, 3045, 4842, 8876, 2626, 8880, 4146, 3347, 6300, 4654,
#         1079],
#        [4789, 8436, 3105, 4107, 6743, 3418, 6131, 1084, 9592, 7582, 3606,
#         6797],
#        [3175, 4944, 3869, 1891, 4163, 9500, 2030, 3906, 4375, 5604, 5778,
#         5689],
#        [9760, 4457, 7789, 9787, 3790, 9262, 6999, 1091, 8840, 6854, 3785,
#         9200],
#        [1995, 7827, 4249, 2984, 2703, 7172, 5290, 7784, 7623, 9143, 2314,
#         5473],
#        [ 327, 8427, 3250,  706, 5878, 1038, 8703, 3811, 9465, 1066, 4530,
#          751],
#        [8319,  220, 9102, 1202, 8212, 7931, 7658, 3833, 6211, 4768,  665,
#         9031],
#        [ 770, 3693, 3454,   26, 1046, 3027, 8992, 1193, 8524,  408, 6136,
#          410],
#        [5547, 7449, 7872, 2565, 8315, 1203, 4737, 5918, 2294, 7932, 7055,
#         8698],
#        [7970, 7510, 3846, 9423, 3756, 7761, 4134, 1395,  933, 1957, 8485,
#         1021]])

# %%
#DECISION VARIABLES

#Paid Quantity
PaidQtyLimit = 10000
P = LpVariable.dicts("Paid_Quantity",(Products,PHorizon),lowBound=0, upBound=PaidQtyLimit, cat='Integer')

#Free Quantity
FreeQtyLimit = 5000
F = LpVariable.dicts("Free_Quantity",(Products,PHorizon),lowBound=0, upBound=FreeQtyLimit, cat='Integer')

#Promo Ratio
#R = LpVariable.dicts("Promo_Ratio",(Products,PHorizon),lowBound=0, upBound=1, cat='Continuous')

#Is Product "i" at Time "t" Promoted?
X = LpVariable.dicts("IsPromoted",(Products,PHorizon),cat='Binary')

# %%
#OBJECTIVE FUNCTION

Total_Paid_Quantity = lpSum(lpSum(P[i][t] for i in Products) for t in PHorizon)

Promo_Model += Total_Paid_Quantity

# %%
#DEMAND SATISFACTION
for i in Products:
    for t in PHorizon:
       Promo_Model += P[i][t] + F[i][t] == Demand[i][t]*(1 + F[i][t]*(1/FreeQtyLimit))
    
#NO FREE WITHOUT PROMOTION
M = FreeQtyLimit
for i in Products:
    for t in PHorizon:
       Promo_Model += F[i][t] <= X[i][t] * M
    
#PROMO RATIO
#for i in Products:
#    for t in PHorizon:
#        Promo_Model += F[i][t] == R[i][t]*Demand[i][t]      

#PROMOTED PRODUCTS AT TIME "t"
for t in PHorizon:
    Promo_Model += lpSum(X[i][t] for i in Products) == 5
    
#PROMO PERIOD FOR PRODUCT "i"  
for i in Products:
    Promo_Model += lpSum(X[i][t] for t in PHorizon) == 6

#TOTAL PAID QUANTITY CAPACITY
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(P[i][t] for t in PHorizon) <= Total_PaidQty_Limit
    
#TOTAL FREE QUANTITY CAPACITY
for i in Products:
    for t in PHorizon:
        Promo_Model += lpSum(F[i][t] for t in PHorizon) <= Total_FreeQty_Limit

# %%
Promo_Model.solve()
# The status of the solution is printed to the screen
print("Status:", LpStatus[Promo_Model.status])
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/baris/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/11/n43tq6bj255drztgc6ydfmdc0000gn/T/d585016325d543d78c99346ca96efacb-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/11/n43tq6bj255drztgc6ydfmdc0000gn/T/d585016325d543d78c99346ca96efacb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 507 COLUMNS
# At line 4948 RHS
# At line 5451 BOUNDS
# At line 5812 ENDATA
# Problem MODEL has 502 rows, 360 columns and 3600 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 679947 - 0.00 seconds
# Cgl0003I 0 fixed, 173 tightened bounds, 63 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 151 tightened bounds, 61 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 152 tightened bounds, 60 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 155 tightened bounds, 59 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 153 tightened bounds, 58 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 151 tightened bounds, 56 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 151 tightened bounds, 56 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 148 tightened bounds, 55 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 149 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0004I processed model has 260 rows, 358 columns (358 integer (120 of which binary)) and 716 elements
# Cbc0038I Initial state - 82 integers unsatisfied sum - 9.07504
# Cbc0038I Pass   1: suminf.    5.13996 (28) obj. -674595 iterations 83
# Cbc0038I Solution found of -674595
# Cbc0038I Branch and bound needed to clear up 28 general integers
# Cbc0038I Full problem 260 rows 358 columns, reduced to 60 rows 120 columns
# Cbc0038I Cleaned solution of -648524
# Cbc0038I Before mini branch and bound, 276 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.37 seconds)
# Cbc0038I Round again with cutoff of -651133
# Cbc0038I Pass   2: suminf.    5.13996 (28) obj. -674595 iterations 0
# Cbc0038I Solution found of -674595
# Cbc0038I Branch and bound needed to clear up 28 general integers
# Cbc0038I Full problem 261 rows 358 columns, reduced to 61 rows 120 columns
# Cbc0038I Mini branch and bound could not fix general integers
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 276 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.66 seconds)
# Cbc0038I After 0.66 seconds - Feasibility pump exiting with objective of -648524 - took 0.62 seconds
# Cbc0012I Integer solution of -648524 found by feasibility pump after 0 iterations and 0 nodes (0.66 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 80 rows 106 columns
# Cbc0031I 26 added rows had average density of 2.1923077
# Cbc0013I At root node, 26 cuts changed objective from -674582.12 to -662312.35 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 8950 row cuts average 2.4 elements, 5778 column cuts (5796 active)  in 0.055 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4986 row cuts average 12.1 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1378 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1965 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 2574 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 2 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.328 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -648524 best solution, best possible -662311.35 (1.35 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 17 rows 26 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 15 rows 22 columns
# Cbc0004I Integer solution of -651282 found after 7552 iterations and 196 nodes (1.86 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 7 rows 14 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 8 rows 16 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 7 rows 14 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 6 rows 12 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 5 rows 10 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 8 rows 16 columns
# Cbc0010I After 1000 nodes, 21 on tree, -651282 best solution, best possible -662311.35 (3.63 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 2 rows 4 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 6 rows 12 columns
# Cbc0010I After 2000 nodes, 75 on tree, -651282 best solution, best possible -662311.35 (5.38 seconds)
# Cbc0010I After 3000 nodes, 42 on tree, -651282 best solution, best possible -662311.35 (6.79 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 7 rows 14 columns
# Cbc0038I Full problem 260 rows 358 columns, reduced to 6 rows 12 columns
# Cbc0010I After 4000 nodes, 19 on tree, -651282 best solution, best possible -662311.35 (8.54 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 5 rows 10 columns
# Cbc0010I After 5000 nodes, 23 on tree, -651282 best solution, best possible -662311.35 (10.49 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 4 rows 8 columns
# Cbc0010I After 6000 nodes, 87 on tree, -651282 best solution, best possible -662311.35 (12.50 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 8 rows 17 columns
# Cbc0010I After 7000 nodes, 10 on tree, -651282 best solution, best possible -662311.35 (13.98 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 16 rows 29 columns
# Cbc0010I After 8000 nodes, 81 on tree, -651282 best solution, best possible -662311.35 (15.89 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 3 rows 6 columns
# Cbc0010I After 9000 nodes, 91 on tree, -651282 best solution, best possible -662311.35 (17.72 seconds)
# Cbc0010I After 10000 nodes, 17 on tree, -651282 best solution, best possible -662311.35 (19.15 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 4 rows 8 columns
# Cbc0010I After 11000 nodes, 47 on tree, -651282 best solution, best possible -662311.35 (20.58 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 11 rows 19 columns
# Cbc0010I After 12000 nodes, 215 on tree, -651282 best solution, best possible -656329 (27.35 seconds)
# Cbc0010I After 13000 nodes, 278 on tree, -651282 best solution, best possible -655818 (31.19 seconds)
# Cbc0010I After 14000 nodes, 292 on tree, -651282 best solution, best possible -655818 (32.81 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 10 rows 17 columns
# Cbc0010I After 15000 nodes, 345 on tree, -651282 best solution, best possible -655468 (35.88 seconds)
# Cbc0010I After 16000 nodes, 371 on tree, -651282 best solution, best possible -655210 (38.44 seconds)
# Cbc0010I After 17000 nodes, 386 on tree, -651282 best solution, best possible -654979.8 (40.90 seconds)
# Cbc0010I After 18000 nodes, 388 on tree, -651282 best solution, best possible -654979.8 (42.46 seconds)
# Cbc0010I After 19000 nodes, 425 on tree, -651282 best solution, best possible -654774 (45.08 seconds)
# Cbc0010I After 20000 nodes, 455 on tree, -651282 best solution, best possible -654600 (47.49 seconds)
# Cbc0010I After 21000 nodes, 470 on tree, -651282 best solution, best possible -654436.57 (49.83 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 10 rows 17 columns
# Cbc0010I After 22000 nodes, 432 on tree, -651282 best solution, best possible -654436.57 (51.33 seconds)
# Cbc0010I After 23000 nodes, 443 on tree, -651282 best solution, best possible -654284 (53.55 seconds)
# Cbc0010I After 24000 nodes, 454 on tree, -651282 best solution, best possible -654158.72 (55.82 seconds)
# Cbc0010I After 25000 nodes, 470 on tree, -651282 best solution, best possible -654023 (58.05 seconds)
# Cbc0010I After 26000 nodes, 473 on tree, -651282 best solution, best possible -654023 (59.57 seconds)
# Cbc0010I After 27000 nodes, 483 on tree, -651282 best solution, best possible -653894 (61.79 seconds)
# Cbc0010I After 28000 nodes, 486 on tree, -651282 best solution, best possible -653782 (64.00 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 14 rows 24 columns
# Cbc0010I After 29000 nodes, 493 on tree, -651282 best solution, best possible -653666 (66.15 seconds)
# Cbc0010I After 30000 nodes, 486 on tree, -651282 best solution, best possible -653666 (67.41 seconds)
# Cbc0010I After 31000 nodes, 501 on tree, -651282 best solution, best possible -653562 (69.64 seconds)
# Cbc0010I After 32000 nodes, 516 on tree, -651282 best solution, best possible -653455 (71.76 seconds)
# Cbc0010I After 33000 nodes, 517 on tree, -651282 best solution, best possible -653355 (73.88 seconds)
# Cbc0010I After 34000 nodes, 528 on tree, -651282 best solution, best possible -653355 (75.30 seconds)
# Cbc0010I After 35000 nodes, 531 on tree, -651282 best solution, best possible -653264 (77.36 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 16 rows 26 columns
# Cbc0010I After 36000 nodes, 532 on tree, -651282 best solution, best possible -653174 (79.40 seconds)
# Cbc0010I After 37000 nodes, 533 on tree, -651282 best solution, best possible -653086.74 (81.39 seconds)
# Cbc0010I After 38000 nodes, 542 on tree, -651282 best solution, best possible -653086.74 (82.79 seconds)
# Cbc0010I After 39000 nodes, 544 on tree, -651282 best solution, best possible -652998.82 (84.82 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 5 rows 10 columns
# Cbc0010I After 40000 nodes, 546 on tree, -651282 best solution, best possible -652912 (86.82 seconds)
# Cbc0010I After 41000 nodes, 553 on tree, -651282 best solution, best possible -652831 (88.78 seconds)
# Cbc0010I After 42000 nodes, 536 on tree, -651282 best solution, best possible -652831 (90.28 seconds)
# Cbc0010I After 43000 nodes, 536 on tree, -651282 best solution, best possible -652749 (92.29 seconds)
# Cbc0010I After 44000 nodes, 538 on tree, -651282 best solution, best possible -652669 (94.26 seconds)
# Cbc0010I After 45000 nodes, 538 on tree, -651282 best solution, best possible -652596 (96.19 seconds)
# Cbc0010I After 46000 nodes, 515 on tree, -651282 best solution, best possible -652596 (97.69 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 9 rows 15 columns
# Cbc0010I After 47000 nodes, 520 on tree, -651282 best solution, best possible -652514.64 (99.70 seconds)
# Cbc0010I After 48000 nodes, 521 on tree, -651282 best solution, best possible -652429 (101.67 seconds)
# Cbc0010I After 49000 nodes, 517 on tree, -651282 best solution, best possible -652359 (103.59 seconds)
# Cbc0010I After 50000 nodes, 502 on tree, -651282 best solution, best possible -652359 (105.05 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 15 rows 24 columns
# Cbc0010I After 51000 nodes, 501 on tree, -651282 best solution, best possible -652269 (106.94 seconds)
# Cbc0010I After 52000 nodes, 504 on tree, -651282 best solution, best possible -652197.6 (108.85 seconds)
# Cbc0010I After 53000 nodes, 504 on tree, -651282 best solution, best possible -652127 (110.69 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 7 rows 11 columns
# Cbc0010I After 54000 nodes, 476 on tree, -651282 best solution, best possible -652127 (112.11 seconds)
# Cbc0010I After 55000 nodes, 482 on tree, -651282 best solution, best possible -652048 (114.00 seconds)
# Cbc0010I After 56000 nodes, 481 on tree, -651282 best solution, best possible -651970.62 (115.89 seconds)
# Cbc0010I After 57000 nodes, 482 on tree, -651282 best solution, best possible -651894 (117.77 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 6 rows 12 columns
# Cbc0010I After 58000 nodes, 449 on tree, -651282 best solution, best possible -651894 (119.17 seconds)
# Cbc0010I After 59000 nodes, 446 on tree, -651282 best solution, best possible -651809 (121.01 seconds)
# Cbc0010I After 60000 nodes, 442 on tree, -651282 best solution, best possible -651733 (122.85 seconds)
# Cbc0010I After 61000 nodes, 441 on tree, -651282 best solution, best possible -651658 (124.71 seconds)
# Cbc0038I Full problem 260 rows 358 columns, reduced to 6 rows 12 columns
# Cbc0010I After 62000 nodes, 365 on tree, -651282 best solution, best possible -651658 (126.18 seconds)
# Cbc0010I After 63000 nodes, 360 on tree, -651282 best solution, best possible -651566 (128.01 seconds)
# Cbc0010I After 64000 nodes, 353 on tree, -651282 best solution, best possible -651467 (129.83 seconds)
# Cbc0010I After 65000 nodes, 274 on tree, -651282 best solution, best possible -651375 (131.51 seconds)
# Cbc0010I After 66000 nodes, 22 on tree, -651282 best solution, best possible -651357 (132.71 seconds)
# Cbc0001I Search completed - best objective -651282, took 728032 iterations and 66068 nodes (132.78 seconds)
# Cbc0032I Strong branching done 82210 times (46703 iterations), fathomed 555 nodes and fixed 31990 variables
# Cbc0035I Maximum depth 155, 6131 variables fixed on reduced cost
# Cuts at root node changed objective from -674601 to -662311
# Probing was tried 18231 times and created 178934 cuts of which 18 were active after adding rounds of cuts (1.572 seconds)
# Gomory was tried 18194 times and created 97043 cuts of which 0 were active after adding rounds of cuts (1.110 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.033 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 18194 times and created 4842 cuts of which 0 were active after adding rounds of cuts (0.831 seconds)
# FlowCover was tried 18194 times and created 5832 cuts of which 0 were active after adding rounds of cuts (2.448 seconds)
# TwoMirCuts was tried 18194 times and created 95828 cuts of which 0 were active after adding rounds of cuts (1.731 seconds)
# ZeroHalf was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.328 seconds)
#
# Result - Optimal solution found
#
# Objective value:                651282.00000000
# Enumerated nodes:               66068
# Total iterations:               728032
# Time (CPU seconds):             132.30
# Time (Wallclock seconds):       132.78
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       132.31   (Wallclock seconds):       132.79
#
# Status: Optimal

# %%
# OUTPUT

# OPTIMIZED OBJECTIVE FUNCTION
print("Optimal Total Paid Quantity = ", pulp.value(Promo_Model.objective),"\n")

# PRINTS VARIABLES AND OPTIMAL VALUES
for v in Promo_Model.variables():
    print(v.name, "=", v.varValue)
# Out:
# Optimal Total Paid Quantity =  651282.0
#
# Free_Quantity_0_0 = 0.0
# Free_Quantity_0_1 = 0.0
# Free_Quantity_0_10 = 0.0
# Free_Quantity_0_11 = 0.0
# Free_Quantity_0_2 = 0.0
# Free_Quantity_0_3 = 0.0
# Free_Quantity_0_4 = 1250.0
# Free_Quantity_0_5 = 0.0
# Free_Quantity_0_6 = 1375.0
# Free_Quantity_0_7 = 0.0
# Free_Quantity_0_8 = 0.0
# Free_Quantity_0_9 = 5000.0
# Free_Quantity_1_0 = 0.0
# Free_Quantity_1_1 = 1250.0
# Free_Quantity_1_10 = 0.0
# Free_Quantity_1_11 = 5000.0
# Free_Quantity_1_2 = 0.0
# Free_Quantity_1_3 = 0.0
# Free_Quantity_1_4 = 5000.0
# Free_Quantity_1_5 = 0.0
# Free_Quantity_1_6 = 5000.0
# Free_Quantity_1_7 = 0.0
# Free_Quantity_1_8 = 0.0
# Free_Quantity_1_9 = 2500.0
# Free_Quantity_2_0 = 0.0
# Free_Quantity_2_1 = 0.0
# Free_Quantity_2_10 = 5000.0
# Free_Quantity_2_11 = 5000.0
# Free_Quantity_2_2 = 0.0
# Free_Quantity_2_3 = 0.0
# Free_Quantity_2_4 = 0.0
# Free_Quantity_2_5 = 550.0
# Free_Quantity_2_6 = 0.0
# Free_Quantity_2_7 = 0.0
# Free_Quantity_2_8 = 0.0
# Free_Quantity_2_9 = 5000.0
# Free_Quantity_3_0 = 250.0
# Free_Quantity_3_1 = 0.0
# Free_Quantity_3_10 = 0.0
# Free_Quantity_3_11 = 950.0
# Free_Quantity_3_2 = 0.0
# Free_Quantity_3_3 = 0.0
# Free_Quantity_3_4 = 0.0
# Free_Quantity_3_5 = 0.0
# Free_Quantity_3_6 = 5000.0
# Free_Quantity_3_7 = 0.0
# Free_Quantity_3_8 = 1500.0
# Free_Quantity_3_9 = 5000.0
# Free_Quantity_4_0 = 0.0
# Free_Quantity_4_1 = 0.0
# Free_Quantity_4_10 = 0.0
# Free_Quantity_4_11 = 5000.0
# Free_Quantity_4_2 = 0.0
# Free_Quantity_4_3 = 0.0
# Free_Quantity_4_4 = 0.0
# Free_Quantity_4_5 = 5000.0
# Free_Quantity_4_6 = 0.0
# Free_Quantity_4_7 = 3750.0
# Free_Quantity_4_8 = 0.0
# Free_Quantity_4_9 = 0.0
# Free_Quantity_5_0 = 0.0
# Free_Quantity_5_1 = 0.0
# Free_Quantity_5_10 = 0.0
# Free_Quantity_5_11 = 0.0
# Free_Quantity_5_2 = 0.0
# Free_Quantity_5_3 = 0.0
# Free_Quantity_5_4 = 5000.0
# Free_Quantity_5_5 = 0.0
# Free_Quantity_5_6 = 0.0
# Free_Quantity_5_7 = 0.0
# Free_Quantity_5_8 = 0.0
# Free_Quantity_5_9 = 0.0
# Free_Quantity_6_0 = 0.0
# Free_Quantity_6_1 = 0.0
# Free_Quantity_6_10 = 0.0
# Free_Quantity_6_11 = 0.0
# Free_Quantity_6_2 = 0.0
# Free_Quantity_6_3 = 0.0
# Free_Quantity_6_4 = 2500.0
# Free_Quantity_6_5 = 0.0
# Free_Quantity_6_6 = 2500.0
# Free_Quantity_6_7 = 0.0
# Free_Quantity_6_8 = 5000.0
# Free_Quantity_6_9 = 0.0
# Free_Quantity_7_0 = 0.0
# Free_Quantity_7_1 = 0.0
# Free_Quantity_7_10 = 5000.0
# Free_Quantity_7_11 = 0.0
# Free_Quantity_7_2 = 0.0
# Free_Quantity_7_3 = 0.0
# Free_Quantity_7_4 = 0.0
# Free_Quantity_7_5 = 0.0
# Free_Quantity_7_6 = 1250.0
# Free_Quantity_7_7 = 0.0
# Free_Quantity_7_8 = 1250.0
# Free_Quantity_7_9 = 0.0
# Free_Quantity_8_0 = 0.0
# Free_Quantity_8_1 = 5000.0
# Free_Quantity_8_10 = 5000.0
# Free_Quantity_8_11 = 0.0
# Free_Quantity_8_2 = 3125.0
# Free_Quantity_8_3 = 0.0
# Free_Quantity_8_4 = 2000.0
# Free_Quantity_8_5 = 0.0
# Free_Quantity_8_6 = 0.0
# Free_Quantity_8_7 = 5000.0
# Free_Quantity_8_8 = 0.0
# Free_Quantity_8_9 = 2500.0
# Free_Quantity_9_0 = 3000.0
# Free_Quantity_9_1 = 4500.0
# Free_Quantity_9_10 = 2000.0
# Free_Quantity_9_11 = 0.0
# Free_Quantity_9_2 = 0.0
# Free_Quantity_9_3 = 0.0
# Free_Quantity_9_4 = 0.0
# Free_Quantity_9_5 = 0.0
# Free_Quantity_9_6 = 0.0
# Free_Quantity_9_7 = 0.0
# Free_Quantity_9_8 = 0.0
# Free_Quantity_9_9 = 0.0
# IsPromoted_0_0 = 1.0
# IsPromoted_0_1 = 0.0
# IsPromoted_0_10 = 0.0
# IsPromoted_0_11 = 0.0
# IsPromoted_0_2 = 0.0
# IsPromoted_0_3 = 1.0
# IsPromoted_0_4 = 1.0
# IsPromoted_0_5 = 0.0
# IsPromoted_0_6 = 1.0
# IsPromoted_0_7 = 1.0
# IsPromoted_0_8 = 0.0
# IsPromoted_0_9 = 1.0
# IsPromoted_1_0 = 0.0
# IsPromoted_1_1 = 1.0
# IsPromoted_1_10 = 0.0
# IsPromoted_1_11 = 1.0
# IsPromoted_1_2 = 0.0
# IsPromoted_1_3 = 0.0
# IsPromoted_1_4 = 1.0
# IsPromoted_1_5 = 0.0
# IsPromoted_1_6 = 1.0
# IsPromoted_1_7 = 0.0
# IsPromoted_1_8 = 1.0
# IsPromoted_1_9 = 1.0
# IsPromoted_2_0 = 1.0
# IsPromoted_2_1 = 0.0
# IsPromoted_2_10 = 1.0
# IsPromoted_2_11 = 1.0
# IsPromoted_2_2 = 0.0
# IsPromoted_2_3 = 1.0
# IsPromoted_2_4 = 0.0
# IsPromoted_2_5 = 1.0
# IsPromoted_2_6 = 0.0
# IsPromoted_2_7 = 0.0
# IsPromoted_2_8 = 0.0
# IsPromoted_2_9 = 1.0
# IsPromoted_3_0 = 1.0
# IsPromoted_3_1 = 0.0
# IsPromoted_3_10 = 0.0
# IsPromoted_3_11 = 1.0
# IsPromoted_3_2 = 1.0
# IsPromoted_3_3 = 0.0
# IsPromoted_3_4 = 0.0
# IsPromoted_3_5 = 0.0
# IsPromoted_3_6 = 1.0
# IsPromoted_3_7 = 0.0
# IsPromoted_3_8 = 1.0
# IsPromoted_3_9 = 1.0
# IsPromoted_4_0 = 0.0
# IsPromoted_4_1 = 1.0
# IsPromoted_4_10 = 0.0
# IsPromoted_4_11 = 1.0
# IsPromoted_4_2 = 0.0
# IsPromoted_4_3 = 1.0
# IsPromoted_4_4 = 0.0
# IsPromoted_4_5 = 1.0
# IsPromoted_4_6 = 0.0
# IsPromoted_4_7 = 1.0
# IsPromoted_4_8 = 1.0
# IsPromoted_4_9 = 0.0
# IsPromoted_5_0 = 0.0
# IsPromoted_5_1 = 1.0
# IsPromoted_5_10 = 1.0
# IsPromoted_5_11 = 0.0
# IsPromoted_5_2 = 1.0
# IsPromoted_5_3 = 1.0
# IsPromoted_5_4 = 1.0
# IsPromoted_5_5 = 1.0
# IsPromoted_5_6 = 0.0
# IsPromoted_5_7 = 0.0
# IsPromoted_5_8 = 0.0
# IsPromoted_5_9 = 0.0
# IsPromoted_6_0 = 1.0
# IsPromoted_6_1 = 0.0
# IsPromoted_6_10 = 0.0
# IsPromoted_6_11 = 0.0
# IsPromoted_6_2 = 1.0
# IsPromoted_6_3 = 0.0
# IsPromoted_6_4 = 1.0
# IsPromoted_6_5 = 1.0
# IsPromoted_6_6 = 1.0
# IsPromoted_6_7 = 0.0
# IsPromoted_6_8 = 1.0
# IsPromoted_6_9 = 0.0
# IsPromoted_7_0 = 0.0
# IsPromoted_7_1 = 0.0
# IsPromoted_7_10 = 1.0
# IsPromoted_7_11 = 1.0
# IsPromoted_7_2 = 1.0
# IsPromoted_7_3 = 0.0
# IsPromoted_7_4 = 0.0
# IsPromoted_7_5 = 0.0
# IsPromoted_7_6 = 1.0
# IsPromoted_7_7 = 1.0
# IsPromoted_7_8 = 1.0
# IsPromoted_7_9 = 0.0
# IsPromoted_8_0 = 0.0
# IsPromoted_8_1 = 1.0
# IsPromoted_8_10 = 1.0
# IsPromoted_8_11 = 0.0
# IsPromoted_8_2 = 1.0
# IsPromoted_8_3 = 0.0
# IsPromoted_8_4 = 1.0
# IsPromoted_8_5 = 0.0
# IsPromoted_8_6 = 0.0
# IsPromoted_8_7 = 1.0
# IsPromoted_8_8 = 0.0
# IsPromoted_8_9 = 1.0
# IsPromoted_9_0 = 1.0
# IsPromoted_9_1 = 1.0
# IsPromoted_9_10 = 1.0
# IsPromoted_9_11 = 0.0
# IsPromoted_9_2 = 0.0
# IsPromoted_9_3 = 1.0
# IsPromoted_9_4 = 0.0
# IsPromoted_9_5 = 1.0
# IsPromoted_9_6 = 0.0
# IsPromoted_9_7 = 1.0
# IsPromoted_9_8 = 0.0
# IsPromoted_9_9 = 0.0
# Paid_Quantity_0_0 = 4837.0
# Paid_Quantity_0_1 = 4626.0
# Paid_Quantity_0_10 = 4654.0
# Paid_Quantity_0_11 = 1079.0
# Paid_Quantity_0_2 = 3045.0
# Paid_Quantity_0_3 = 4842.0
# Paid_Quantity_0_4 = 9845.0
# Paid_Quantity_0_5 = 2626.0
# Paid_Quantity_0_6 = 9947.0
# Paid_Quantity_0_7 = 4146.0
# Paid_Quantity_0_8 = 3347.0
# Paid_Quantity_0_9 = 7600.0
# Paid_Quantity_1_0 = 4789.0
# Paid_Quantity_1_1 = 9295.0
# Paid_Quantity_1_10 = 3606.0
# Paid_Quantity_1_11 = 8594.0
# Paid_Quantity_1_2 = 3105.0
# Paid_Quantity_1_3 = 4107.0
# Paid_Quantity_1_4 = 8486.0
# Paid_Quantity_1_5 = 3418.0
# Paid_Quantity_1_6 = 7262.0
# Paid_Quantity_1_7 = 1084.0
# Paid_Quantity_1_8 = 9592.0
# Paid_Quantity_1_9 = 8873.0
# Paid_Quantity_2_0 = 3175.0
# Paid_Quantity_2_1 = 4944.0
# Paid_Quantity_2_10 = 6556.0
# Paid_Quantity_2_11 = 6378.0
# Paid_Quantity_2_2 = 3869.0
# Paid_Quantity_2_3 = 1891.0
# Paid_Quantity_2_4 = 4163.0
# Paid_Quantity_2_5 = 9995.0
# Paid_Quantity_2_6 = 2030.0
# Paid_Quantity_2_7 = 3906.0
# Paid_Quantity_2_8 = 4375.0
# Paid_Quantity_2_9 = 6208.0
# Paid_Quantity_3_0 = 9998.0
# Paid_Quantity_3_1 = 4457.0
# Paid_Quantity_3_10 = 3785.0
# Paid_Quantity_3_11 = 9998.0
# Paid_Quantity_3_2 = 7789.0
# Paid_Quantity_3_3 = 9787.0
# Paid_Quantity_3_4 = 3790.0
# Paid_Quantity_3_5 = 9262.0
# Paid_Quantity_3_6 = 8998.0
# Paid_Quantity_3_7 = 1091.0
# Paid_Quantity_3_8 = 9992.0
# Paid_Quantity_3_9 = 8708.0
# Paid_Quantity_4_0 = 1995.0
# Paid_Quantity_4_1 = 7827.0
# Paid_Quantity_4_10 = 2314.0
# Paid_Quantity_4_11 = 5946.0
# Paid_Quantity_4_2 = 4249.0
# Paid_Quantity_4_3 = 2984.0
# Paid_Quantity_4_4 = 2703.0
# Paid_Quantity_4_5 = 9344.0
# Paid_Quantity_4_6 = 5290.0
# Paid_Quantity_4_7 = 9872.0
# Paid_Quantity_4_8 = 7623.0
# Paid_Quantity_4_9 = 9143.0
# Paid_Quantity_5_0 = 327.0
# Paid_Quantity_5_1 = 8427.0
# Paid_Quantity_5_10 = 4530.0
# Paid_Quantity_5_11 = 751.0
# Paid_Quantity_5_2 = 3250.0
# Paid_Quantity_5_3 = 706.0
# Paid_Quantity_5_4 = 6756.0
# Paid_Quantity_5_5 = 1038.0
# Paid_Quantity_5_6 = 8703.0
# Paid_Quantity_5_7 = 3811.0
# Paid_Quantity_5_8 = 9465.0
# Paid_Quantity_5_9 = 1066.0
# Paid_Quantity_6_0 = 8319.0
# Paid_Quantity_6_1 = 220.0
# Paid_Quantity_6_10 = 665.0
# Paid_Quantity_6_11 = 9031.0
# Paid_Quantity_6_2 = 9102.0
# Paid_Quantity_6_3 = 1202.0
# Paid_Quantity_6_4 = 9818.0
# Paid_Quantity_6_5 = 7931.0
# Paid_Quantity_6_6 = 8987.0
# Paid_Quantity_6_7 = 3833.0
# Paid_Quantity_6_8 = 7422.0
# Paid_Quantity_6_9 = 4768.0
# Paid_Quantity_7_0 = 770.0
# Paid_Quantity_7_1 = 3693.0
# Paid_Quantity_7_10 = 7272.0
# Paid_Quantity_7_11 = 410.0
# Paid_Quantity_7_2 = 3454.0
# Paid_Quantity_7_3 = 26.0
# Paid_Quantity_7_4 = 1046.0
# Paid_Quantity_7_5 = 3027.0
# Paid_Quantity_7_6 = 9990.0
# Paid_Quantity_7_7 = 1193.0
# Paid_Quantity_7_8 = 9405.0
# Paid_Quantity_7_9 = 408.0
# Paid_Quantity_8_0 = 5547.0
# Paid_Quantity_8_1 = 9898.0
# Paid_Quantity_8_10 = 9110.0
# Paid_Quantity_8_11 = 8698.0
# Paid_Quantity_8_2 = 9667.0
# Paid_Quantity_8_3 = 2565.0
# Paid_Quantity_8_4 = 9641.0
# Paid_Quantity_8_5 = 1203.0
# Paid_Quantity_8_6 = 4737.0
# Paid_Quantity_8_7 = 6836.0
# Paid_Quantity_8_8 = 2294.0
# Paid_Quantity_8_9 = 9398.0
# Paid_Quantity_9_0 = 9752.0
# Paid_Quantity_9_1 = 9769.0
# Paid_Quantity_9_10 = 9879.0
# Paid_Quantity_9_11 = 1021.0
# Paid_Quantity_9_2 = 3846.0
# Paid_Quantity_9_3 = 9423.0
# Paid_Quantity_9_4 = 3756.0
# Paid_Quantity_9_5 = 7761.0
# Paid_Quantity_9_6 = 4134.0
# Paid_Quantity_9_7 = 1395.0
# Paid_Quantity_9_8 = 933.0
# Paid_Quantity_9_9 = 1957.0

# %%
#PROMO RATIO IS CALCULATED BASED ON THE OPTIMUM P[i][t] AND F[i][t] VALUES
Promo_Ratio = np.zeros((I, T), dtype = float)

for i in Products:
    for t in PHorizon:
        Promo_Ratio[i][t] = (F[i][t].varValue)/(P[i][t].varValue + F[i][t].varValue)

df_Promo_Ratio = pd.DataFrame(Promo_Ratio,
                 index=range(1,I+1),
                 columns=range(1,T+1))
df_Promo_Ratio
# Out:
#           1         2         3    4         5         6         7        8   \
# 1   0.000000  0.000000  0.000000  0.0  0.112663  0.000000  0.121445  0.00000
# 2   0.000000  0.118540  0.000000  0.0  0.370755  0.000000  0.407764  0.00000
# 3   0.000000  0.000000  0.000000  0.0  0.000000  0.052157  0.000000  0.00000
# 4   0.024395  0.000000  0.000000  0.0  0.000000  0.000000  0.357194  0.00000
# 5   0.000000  0.000000  0.000000  0.0  0.000000  0.348578  0.000000  0.27529
# 6   0.000000  0.000000  0.000000  0.0  0.425315  0.000000  0.000000  0.00000
# 7   0.000000  0.000000  0.000000  0.0  0.202955  0.000000  0.217637  0.00000
# 8   0.000000  0.000000  0.000000  0.0  0.000000  0.000000  0.111210  0.00000
# 9   0.000000  0.335616  0.244293  0.0  0.171807  0.000000  0.000000  0.42244
# 10  0.235257  0.315369  0.000000  0.0  0.000000  0.000000  0.000000  0.00000
#
#           9         10        11        12
# 1   0.000000  0.396825  0.000000  0.000000
# 2   0.000000  0.219819  0.000000  0.367809
# 3   0.000000  0.446110  0.432676  0.439445
# 4   0.130526  0.364751  0.000000  0.086774
# 5   0.000000  0.000000  0.000000  0.456788
# 6   0.000000  0.000000  0.000000  0.000000
# 7   0.402512  0.000000  0.000000  0.000000
# 8   0.117316  0.000000  0.407432  0.000000
# 9   0.000000  0.210119  0.354359  0.000000
# 10  0.000000  0.000000  0.168364  0.000000
