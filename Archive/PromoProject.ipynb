# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime as dt
import seaborn as sns

# %%
sales_data = pd.read_parquet("sale_data.parquet")
promo_data = pd.read_excel("promo_data.xlsx")

df_sales = pd.DataFrame(sales_data)
df_promo = pd.DataFrame(promo_data)

# %%
df_sales
# Out:
#                Date  LocationId  MainDistributorId  DistributorId  PackageId
# 0        2023-01-02     2873114            2879223        2878715        615  \
# 1        2023-01-16     2872993            2879223        2878715        615
# 2        2023-01-18     2918671            2879223        2878715        615
# 3        2023-01-19     2919833            2879223        2878715        615
# 4        2023-01-02     2873114            2879223        2878715        616
# ...             ...         ...                ...            ...        ...
# 11422788 2022-12-22     2928593            2927450        2927451       1052
# 11422789 2022-12-12     2928640            2927450        2927451        505
# 11422790 2022-12-27     2928662            2927450        2927451       1052
# 11422791 2022-12-22     2928741            2927450        2927451       1038
# 11422792 2022-12-22     2928741            2927450        2927451       1052
#
#           ProductId       City  District  BrickId  PaidQty  FreeQty
# 0                38    Kütahya    MERKEZ   430002       24       12
# 1                38    Kütahya  ALTINTAŞ   430101        7        3
# 2                38      Afyon    MERKEZ    30002        7        3
# 3                38       Uşak    MERKEZ   640001        7        3
# 4                38    Kütahya    MERKEZ   430002       24       12
# ...             ...        ...       ...      ...      ...      ...
# 11422788         72  Şanlıurfa   SİVEREK   630701        3        0
# 11422789         45  Şanlıurfa   SİVEREK  1000000        5        0
# 11422790         72  Şanlıurfa  AKÇAKALE   630101        5        0
# 11422791         64  Şanlıurfa   SİVEREK  1000000        2        0
# 11422792         72  Şanlıurfa   SİVEREK  1000000       10        0
#
# [9009211 rows x 11 columns]

# %%
df_sales.describe()
# Out:
#                                 Date    LocationId  MainDistributorId
# count                        9009211  9.009211e+06       9.009211e+06  \
# mean   2022-11-24 14:57:01.786793472  2.881123e+06       2.880518e+06
# min              2022-02-01 00:00:00  2.853627e+06       2.879223e+06
# 25%              2022-06-29 00:00:00  2.863949e+06       2.879249e+06
# 50%              2022-12-01 00:00:00  2.873490e+06       2.879260e+06
# 75%              2023-04-14 00:00:00  2.888142e+06       2.879266e+06
# max              2023-09-30 00:00:00  2.931082e+06       2.929489e+06
# std                              NaN  2.276591e+04       6.658115e+03
#
#        DistributorId     PackageId     ProductId       BrickId       PaidQty
# count   9.009211e+06  9.009211e+06  9.009211e+06  9.009211e+06  9.009211e+06  \
# mean    2.881863e+06  3.049116e+03  4.416584e+01  3.315863e+05  6.044765e+00
# min     2.878715e+06  3.170000e+02  1.400000e+01  1.010100e+04  0.000000e+00
# 25%     2.878789e+06  5.020000e+02  2.000000e+01  1.700020e+05  2.000000e+00
# 50%     2.878817e+06  5.410000e+02  3.800000e+01  3.416090e+05  4.000000e+00
# 75%     2.878857e+06  1.038000e+03  6.400000e+01  4.300010e+05  6.000000e+00
# max     2.930513e+06  6.960800e+04  1.630000e+02  1.000000e+06  3.906000e+03
# std     1.049600e+04  1.060543e+04  3.279235e+01  1.978870e+05  1.195648e+01
#
#             FreeQty    PromoRatio
# count  9.009211e+06  9.009211e+06
# mean   5.334650e-01  2.775466e-02
# min    0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00
# max    1.650000e+03  1.000000e+00
# std    4.134231e+00  7.553186e-02

# %%
df_sales[["MainDistributorId", "DistributorId"]].drop_duplicates().groupby(["DistributorId"]).size().reset_index(name='counts')["counts"].unique()
# Out:
# array([1], dtype=int64)

# %%
df_sales[["MainDistributorId", "DistributorId"]].drop_duplicates().groupby(["MainDistributorId"]).size().reset_index(name='counts')
# Out:
#     MainDistributorId  counts
# 0             2879223       1
# 1             2879224       1
# 2             2879231       1
# 3             2879236       1
# 4             2879238       1
# 5             2879239       1
# 6             2879244       1
# 7             2879249      20
# 8             2879254       1
# 9             2879257       1
# 10            2879258       1
# 11            2879260       6
# 12            2879266      26
# 13            2879267       1
# 14            2879270       1
# 15            2879276       1
# 16            2886479       1
# 17            2887564       1
# 18            2888200       1
# 19            2909124       1
# 20            2915715       4
# 21            2918750       1
# 22            2922692       1
# 23            2923480       1
# 24            2927151       1
# 25            2927450       1
# 26            2929489       1

# %%
df_sales["ProductId"].unique() # 20
# Out:
# array([ 38,  49,  20,  21,  14,  39,  32,  41,  16,  30, 148,  45, 138,
#         64,  72,  29,  76,  15,  25, 163], dtype=int64)

# %%
len(df_sales["BrickId"].unique()) # Brick
# Out:
# 1002

# %%
len(df_sales["PackageId"].unique()) # Nedir bu package id?
# Out:
# 84

# %%
df_sales["IsPromoted"] = df_sales["FreeQty"]!=0

# %%
df_sales["PromoRatio"] = df_sales.FreeQty/(df_sales.PaidQty+df_sales.FreeQty)
df_promo["PromoRatio"] = df_promo.FreeQty/(df_promo.PaidQty+df_promo.FreeQty)

# %%
df_sales
# Out:
#                Date  LocationId  MainDistributorId  DistributorId  PackageId
# 0        2023-01-02     2873114            2879223        2878715        615  \
# 1        2023-01-16     2872993            2879223        2878715        615
# 2        2023-01-18     2918671            2879223        2878715        615
# 3        2023-01-19     2919833            2879223        2878715        615
# 4        2023-01-02     2873114            2879223        2878715        616
# ...             ...         ...                ...            ...        ...
# 11422788 2022-12-22     2928593            2927450        2927451       1052
# 11422789 2022-12-12     2928640            2927450        2927451        505
# 11422790 2022-12-27     2928662            2927450        2927451       1052
# 11422791 2022-12-22     2928741            2927450        2927451       1038
# 11422792 2022-12-22     2928741            2927450        2927451       1052
#
#           ProductId       City  District  BrickId  PaidQty  FreeQty
# 0                38    Kütahya    MERKEZ   430002       24       12  \
# 1                38    Kütahya  ALTINTAŞ   430101        7        3
# 2                38      Afyon    MERKEZ    30002        7        3
# 3                38       Uşak    MERKEZ   640001        7        3
# 4                38    Kütahya    MERKEZ   430002       24       12
# ...             ...        ...       ...      ...      ...      ...
# 11422788         72  Şanlıurfa   SİVEREK   630701        3        0
# 11422789         45  Şanlıurfa   SİVEREK  1000000        5        0
# 11422790         72  Şanlıurfa  AKÇAKALE   630101        5        0
# 11422791         64  Şanlıurfa   SİVEREK  1000000        2        0
# 11422792         72  Şanlıurfa   SİVEREK  1000000       10        0
#
#           IsPromoted  PromoRatio
# 0               True    0.333333
# 1               True    0.300000
# 2               True    0.300000
# 3               True    0.300000
# 4               True    0.333333
# ...              ...         ...
# 11422788       False    0.000000
# 11422789       False    0.000000
# 11422790       False    0.000000
# 11422791       False    0.000000
# 11422792       False    0.000000
#
# [9009211 rows x 13 columns]

# %%
corr_matrix_a = df_sales[["PaidQty", "FreeQty", "IsPromoted", "PromoRatio"]].corr()

# %%
sns.heatmap(corr_matrix_a, annot=True)
plt.show()

# %%
ts_a = df_sales[df_sales["ProductId"]==14]
plt.plot(ts_a["Date"], ts_a["PaidQty"])
plt.plot(ts_a["Date"], ts_a["FreeQty"])

# %%
df_promo
# Her promosyon aralığında günlük ortalama satışı buraya sütun olarak ekle
# Col1 = Kaç defa değerlendirilmiş barem
# Col2 = Toplam satış
# Out:
#       MProductId  BeginDate             EndDate  PaidQty  FreeQty
# 0             14 2022-01-01 2022-01-31 23:30:00        6        2
# 1             14 2022-01-01 2022-01-31 23:30:00       12        5
# 2             14 2022-01-01 2022-01-31 23:30:00       24       12
# 3             14 2022-02-01 2022-02-28 23:30:00        6        2
# 4             14 2022-02-01 2022-02-28 23:30:00       12        5
# ...          ...        ...                 ...      ...      ...
# 1401         148 2023-10-10 2023-10-12 23:30:00       10        1
# 1402         148 2023-10-10 2023-10-12 23:30:00       10        4
# 1403         148 2023-10-10 2023-10-12 23:30:00       25        3
# 1404         148 2023-10-10 2023-10-12 23:30:00       50       10
# 1405         148 2023-10-10 2023-10-12 23:30:00      100       25
#
# [1406 rows x 5 columns]

# %%
df_promo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1406 entries, 0 to 1405
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MProductId  1406 non-null   int64
#  1   BeginDate   1406 non-null   datetime64[ns]
#  2   EndDate     1406 non-null   datetime64[ns]
#  3   PaidQty     1406 non-null   int64
#  4   FreeQty     1406 non-null   int64
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 55.1 KB

# %%
df_promo["PromoPeriod"] = df_promo.EndDate - df_promo.BeginDate

mean_sales = (df_sales.PaidQty.mean(), df_sales.FreeQty.mean(), df_sales.PromoRatio.mean())
mean_promo = (df_promo.PaidQty.mean(), df_promo.FreeQty.mean(), df_promo.PromoRatio.mean())
mean_period = df_promo.PromoPeriod.mean()

# %%
print("Sales Data Averages")
print("(Paid Quantity, Free Quantity, Promotion Ratio) = ", mean_sales)
# Out:
# Sales Data Averages
# (Paid Quantity, Free Quantity, Promotion Ratio) =  (6.0447649633247575, 0.5334650281806032, 0.02775465564209698)

# %%
print("Promotion Data Averages")
print("(Paid Quantity, Free Quantity, Promotion Ratio) = ", mean_promo)
# Out:
# Promotion Data Averages
# (Paid Quantity, Free Quantity, Promotion Ratio) =  (22.4551920341394, 8.333570412517782, 0.20771934923592666)

# %%
print("Average Promotion Period = ", mean_period)
# Out:
# Average Promotion Period =  19 days 11:33:01.792318634

# %%
print("Sales Data - Product Count = ", len(set(df_sales.ProductId)))
print("Promotion Data - Product Count = ", len(set(df_promo.MProductId)))
# Out:
# Sales Data - Product Count =  20
# Promotion Data - Product Count =  13
